# %% [markdown]
# <a href="https://colab.research.google.com/github/ibmkeiba/1_WebScraper/blob/main/netkeiba_4_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **【netkeiba.com】 本番 Stage4 #2**
#
# > **今月分のレース一覧とレース情報/結果を自動的に取得(SQLite出力)**

# %% [markdown]
# * urllib, selenium(chromium) でアクセス
# * BeaurifulSoupで解析
# * レースカレンダーからレースがある日を取得
#
#     【取得するレース情報】（16）
#         ymd, date, menu, place, r, title, start_time, distance, race_type, number, prize, weather, course_status, grade, race_id, url
#
#     【取得するレース結果】（19）
#         rank, waku, umaban, bamei, bamei_url, sexage, handicap, jockey, jockey_url, racetime, difference, popular, odds, furlong3, corner_rank, stable, trainer_url, weight, race_id
#
# > **参考URL**
#
# * 【netkeiba.com】トップページ (https://www.netkeiba.com/)
# * 【netkeiba.com】開催一覧　(https://race.netkeiba.com/top/calendar.html)
# * 【netkeiba.com】開催一覧 (年月指定) (https://race.netkeiba.com/top/calendar.html?year=2021&month=8)
# * 【netkeiba.com】開催レース一覧（特定日） (https://race.netkeiba.com/top/race_list.html?kaisai_date=20210801)

# %% [markdown]
# ## **初期設定**

# %% [markdown]
# ### **ライブラリインポート**

# %%
# choromiumとseleniumをインストール
# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# !pip install selenium
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Get:2 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:10 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [68.5 kB]
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:12 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:13 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:14 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,365 kB]
# Get:15 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [606 kB]
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,429 kB]
# Get:19 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,802 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,800 kB]
# Get:22 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [922 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [638 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,208 kB]
# Get:25 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [42.0 kB]
# Fetched 13.2 MB in 4s (3,581 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-codecs-ffmpeg-extra
# Suggested packages:
#   webaccounts-chromium-extension unity-chromium-extension
# The following NEW packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-chromedriver
#   chromium-codecs-ffmpeg-extra
# 0 upgraded, 4 newly installed, 0 to remove and 80 not upgraded.
# Need to get 92.6 MB of archives.
# After this operation, 317 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-codecs-ffmpeg-extra amd64 93.0.4577.63-0ubuntu0.18.04.1 [1,135 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser amd64 93.0.4577.63-0ubuntu0.18.04.1 [82.4 MB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser-l10n all 93.0.4577.63-0ubuntu0.18.04.1 [4,133 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-chromedriver amd64 93.0.4577.63-0ubuntu0.18.04.1 [4,961 kB]
# Fetched 92.6 MB in 3s (28.0 MB/s)
# Selecting previously unselected package chromium-codecs-ffmpeg-extra.
# (Reading database ... 155013 files and directories currently installed.)
# Preparing to unpack .../chromium-codecs-ffmpeg-extra_93.0.4577.63-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-codecs-ffmpeg-extra (93.0.4577.63-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-browser.
# Preparing to unpack .../chromium-browser_93.0.4577.63-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-browser (93.0.4577.63-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-browser-l10n.
# Preparing to unpack .../chromium-browser-l10n_93.0.4577.63-0ubuntu0.18.04.1_all.deb ...
# Unpacking chromium-browser-l10n (93.0.4577.63-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-chromedriver.
# Preparing to unpack .../chromium-chromedriver_93.0.4577.63-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-chromedriver (93.0.4577.63-0ubuntu0.18.04.1) ...
# Setting up chromium-codecs-ffmpeg-extra (93.0.4577.63-0ubuntu0.18.04.1) ...
# Setting up chromium-browser (93.0.4577.63-0ubuntu0.18.04.1) ...
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# Setting up chromium-chromedriver (93.0.4577.63-0ubuntu0.18.04.1) ...
# Setting up chromium-browser-l10n (93.0.4577.63-0ubuntu0.18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# cp: '/usr/lib/chromium-browser/chromedriver' and '/usr/bin/chromedriver' are the same file
# Collecting selenium
#   Downloading selenium-3.141.0-py2.py3-none-any.whl (904 kB)
#      |████████████████████████████████| 904 kB 26.8 MB/s
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from selenium) (1.24.3)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0

# %%
# ライブラリのインポート
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys

# %%
# ライブラリのインポート
from urllib import request as req
from bs4 import BeautifulSoup

import pandas as pd
import numpy as np
import time
import shutil
import sqlite3

# %% [markdown]
# ## **ユーザー関数**

# %% [markdown]
# ### **①レース開催日の取得**

# %%
# URLからソースコードを取得する関数 <urllib>  【url > soup】
def my_request(url):

    # URLを開く
    res = req.urlopen(url)

    # URLのソースコードを取得
    soup = BeautifulSoup(res, 'html.parser')

    # 暗黙的待機（サーバーの負荷軽減目的）
    time.sleep(0.1)
    
    return soup

# %%
# 開催一覧のソースコードから選択中の年月を抽出する関数 【soup > 表示している開催一覧ページの年月（文字列型）】

def my_selected_ym(soup):

    # 選択中の年 > 例 2021
    selected_y = soup.select_one('select#cal_select_year option[selected@selected]').text

    # 選択中の月 > 例 8
    selected_m = soup.select_one('div.RaceNumWrap.CalendarMonth ul li.Active a').text.replace('月', '')

    # 選択中の年月の6桁文字表記 例 202109
    selected_ym = selected_y + selected_m.zfill(2)

    return selected_ym

# %%
# 開催一覧のURLから現在の年月と開催がある日を取得 【url > ym（文字列型）, days（整数のリスト型）】
def my_get_raceday_from_url(url_calendar='https://race.netkeiba.com/top/calendar.html', ymd_list=None):

    # URLのソースコードを取得
    soup = my_request(url_calendar)

    # 表示中の年月を取得
    ym = my_selected_ym(soup)

    #レース開催がある日のエレメント（なければ []）
    race_day_elements = soup.select('table.Calendar_Table td.RaceCellBox a')

    # 開催レースが月に一度もなければこれまでの開催日リストを返す
    if race_day_elements == []:
        return ymd_list

    # ymd_listがなければ初期設定
    ymd_list = [] if ymd_list is None else ymd_list
    
    # レース開催がある日を回す
    for ele in race_day_elements:
        
        # レース開催日 例 5
        day = int(ele.select_one('span.Day').text)

        # リストに追加
        ymd_list.append(ym + str(day).zfill(2))

    # 翌月の６桁文字表記（文字列型）
    ym_next = str(int(ym[:4]) + int(ym[4:])//12) + str(int(ym[4:])%12+1).zfill(2)

    # 翌月の開催一覧カレンダーURL
    url_calendar_next = 'https://race.netkeiba.com/top/calendar.html?year=' + ym_next[:4] + '&month=' + str(int(ym_next[4:]))

    return my_get_raceday_from_url(url_calendar_next, ymd_list)

# %% [markdown]
# ### **②開催レース一覧**

# %%
# ドライバーを起動 【 - > driver 】
def my_start_driver():

    # オプション設定（★　Colabでそのまま使用できる設定 ★）
    options = webdriver.ChromeOptions()
    options.add_argument('--headless') # Colabではヘッドレス必須*
    options.add_argument('--no-sandbox') # Colab環境でのヘッドレスで必須*
    options.add_argument('--disable-gpu') # soup.prettify() の実行に必要
    options.add_argument('--disable-dev-shm-usage') # メモリ不足回避に有効

    # ドライバーを起動
    driver = webdriver.Chrome('chromedriver', options=options)

    # 要素が見つかるまでの待機時間(秒)を設定
    driver.implicitly_wait(5)

    return driver

# %%
# 指定URLのソースコードを取得 【 url > soup 】
def my_get_source_driver(url):

    global driver

    # もしグローバル変数にdriverがなければ起動
    try:
        driver.current_url
    except:
        driver = my_start_driver()
        print('■ driverを起動しました\n')

    # ブラウザでURLにアクセス
    driver.get(url)

    # ソースコードをBeautifulSopuに変換
    html = driver.page_source.encode('utf-8')
    soup = BeautifulSoup(html, 'html.parser')

    return soup

# %%
# 目的のレースのエレメントから情報を取得
def my_race_info(race_element):

    # レースURL 'https://', race_url
    race_url = race_element.select_one('a.').attrs['href'].replace('..', 'https://race.netkeiba.com')

    # レースID
    race_id = race_url.split('?race_id=')[1].split('&')[0]

    # レース番 '1R', r
    r = race_element.select_one('a. div.Race_Num span').text

    # レースタイトル '3歳未勝利', title
    title = race_element.select_one('a. span.ItemTitle').text

    # 開始時刻 '10:10 ', time
    start_time = race_element.select_one('a. span.RaceList_Itemtime').text

    # コースタイプと距離 'ダ1200m', distance
    #distance = race_element.select_one('a. span.RaceList_ItemLong').text
    
    try:
        distance = race_element.select_one('a. span.RaceList_ItemLong').text

    except AttributeError:
        distance = race_element.select('a. div.RaceData span')[1].text
    
    except:
        print('◆ Select error, ', 'distance ↓')
        distance = ''

    # 出場馬数 '16頭', number
    number = race_element.select_one('a. span.RaceList_Itemnumber').text.replace(' ','')

    # レースグレード, '3', grade
    try:
        grade = race_element.select_one('a. span.Icon_GradeType').attrs['class']
    except: # 存在しない場合
        grade = ''
    else: # 存在する場合
        grade = grade[1].replace('Icon_GradeType', '')

    return [r, race_id, start_time, title, grade, number, distance, race_url]

# %%
# ②開催レース一覧のソースコードから全レースの情報を取得 【 soup > DataFrame 】
def my_race_list(soup):

    # 1日分のレース情報を格納するリスト
    races_list = []

    # 開催年月日（ymd） 文字列型
    ymd = soup.select_one('ul#date_list_sub li.Active').attrs['date']

    # 開催日（曜日）
    date = soup.select_one('ul#date_list_sub li.Active a').attrs['title']

    # 開催場所のエレメントリスト > 3箇所
    place_elelments = soup.select('div.RaceList_Box > dl.RaceList_DataList')

    # 開催場所を回す
    for i, place_ele in enumerate(place_elelments):

        # 開催場所
        place = place_ele.select_one('p.RaceList_DataTitle').text.split(' ')[1]

        # レース一覧のエレメントリスト
        race_elements = place_ele.select('dd.RaceList_Data ul li')

        # レース会場名とレース数を表示
        print('・{}年{}　> {} 【{}】 {} レース'.format(ymd[:4], date, i+1, place, len(race_elements)))

        # レースを回す
        for j, race_ele in enumerate(race_elements):

            # レースのエレメントから情報を取得
            race_list = my_race_info(race_ele)
            # レース情報を表示
            print(race_list)

            # 1日分のレース情報に追加
            races_list.append([int(ymd), date, place] + race_list)
            
    # 1日分のレース情報をDataFrame形式に変換
    ymd_df = pd.DataFrame(races_list, index=None, columns=['ymd', 'date', 'place', 'r', 'race_id', 'start_time', 'title', 'grade', 'number', 'distance', 'url'])

    return ymd_df

# %% [markdown]
# ### **③レース出馬表・結果**

# %%
# gradeが指定したgradeか判定
def my_grade_check(grade, grade_lim=None):

    # グレード指定がない場合
    if grade_lim == None:
        return 'pass'
    # グレード指定がある場合
    elif grade == '':
        return 'skip'
    elif int(grade) > grade_lim:
        return 'skip'
    else:
        return 'pass'

# %%
# 出馬表/結果・払戻からレースの情報を取得 【 soup > list 】
def my_result1(soup):

    # 選択されているサブメニュー（出馬表 / 結果・払戻）
    menu = soup.select_one('ul.RaceMainMenu li a.Active').attrs['title']

    # レース開催日
    date = soup.select_one('dl#RaceList_DateList > dd.Active a').text

    # 開催場所
    try:
        place = soup.select_one('div.RaceKaisaiWrap ul li.Active a').text
    except:
        place = soup.select('div.RaceList_NameBox div.RaceData02 span')[1].text

    # レース番号
    race_num = soup.select_one('div.RaceList_NameBox span.RaceNum').text

    # レース名
    title = soup.select_one('div.RaceList_NameBox div.RaceName').text.replace('\n', '')

    # 発走時刻
    start_time = soup.select_one('div.RaceList_NameBox div.RaceData01').text.replace('\n', '').split('発走')[0]

    # 距離
    distance = soup.select_one('div.RaceList_NameBox div.RaceData01 span').text

    # レース種別 (要注意)
    race_type = soup.select('div.RaceList_NameBox div.RaceData02 span')[3].text

    # 出馬数
    number = soup.select('div.RaceList_NameBox div.RaceData02 span')[7].text

    # 賞金金額[万円]
    prize = soup.select('div.RaceList_NameBox div.RaceData02 span')[8].text.replace('本賞金:', '').replace('万円', '').replace(',', '')

    result1_list = [date, menu, place, race_num, title, start_time, distance, race_type, number, prize]

    # 選択されているメニューが'結果・払戻'の場合
    if menu == '結果・払戻':

        # 天候 (結果・払戻 限定)
        weather = soup.select_one('div.RaceList_NameBox div.RaceData01').text.split('天候:')[1].split('\n')[0]

        # 馬場の状態 (結果・払戻 限定)
        course_status = soup.select('div.RaceList_NameBox div.RaceData01 span')[-1].text.split('馬場:')[1]

        result1_list = result1_list + [weather, course_status]

    # 選択されているメニューが'出馬表'の場合
    else:
        result1_list = result1_list + ['', '']

    return result1_list

# %%
# 【結果・払戻】の１頭分のエレメントから、情報を取得するユーザ関数
def my_result2a(horse_ele):

    # 【結果・払戻】の辞書
    result_dic = {}

    # 着順 rank
    try:
        result_dic['rank'] = int(horse_ele.select_one('td.Result_Num > div.Rank').text)
    except:
        return '取り消し'

    # 枠 waku
    result_dic['waku'] = horse_ele.select('td.Num div')[0].text

    # 馬番 umaban
    result_dic['umaban'] = horse_ele.select('td.Num div')[1].text

    # 馬名 bamei
    result_dic['bamei'] = horse_ele.select_one('td.Horse_Info span.Horse_Name a').text

    # 馬のURL bamei_url
    result_dic['bamei_url'] = horse_ele.select_one('td.Horse_Info span.Horse_Name a').attrs['href']

    # 性齢 sexage
    result_dic['sexage'] = horse_ele.select_one('td.Horse_Info span.Lgt_Txt').text.replace('\n', '')

    # 斤量 handicap
    result_dic['handicap'] = horse_ele.select_one('span.JockeyWeight').text

    try:
        # 騎手 jockey
        result_dic['jockey'] = horse_ele.select_one('td.Jockey a').text.replace(' ', '')

        # 騎手のURL jockey_url
        result_dic['jockey_url'] = horse_ele.select_one('td.Jockey a').attrs['href']
    except:
        # 騎手 jockey
        result_dic['jockey'] = horse_ele.select_one('td.Jockey').text.replace('\n', '').replace(' ', '')

        # 騎手のURL jockey_url
        result_dic['jockey_url'] = ''   

    # タイム racetime
    result_dic['racetime'] = horse_ele.select_one('span.RaceTime').text

    # 着差 difference
    result_dic['difference'] = horse_ele.select('span.RaceTime')[1].text

    # 人気 popular
    result_dic['popular'] = horse_ele.select_one('span.OddsPeople').text

    # 単勝オッズ odds
    result_dic['odds'] = horse_ele.select('td.Odds span')[1].text

    # 後3F　furlong3
    result_dic['furlong3'] = horse_ele.select('td.Time')[2].text.replace('\n', '')

    # コーナー通過順 corner_rank
    result_dic['corner_rank'] = horse_ele.select_one('td.PassageRate').text.replace('\n', '')

    # 厩舎(施設名) stable
    result_dic['stable'] = horse_ele.select_one('td.Trainer span').text

    # 厩舎(調教師) trainer
    result_dic['trainer'] = horse_ele.select_one('td.Trainer a').text

    # 厩舎(調教師)のURL trainer_url
    result_dic['trainer_url'] = horse_ele.select_one('td.Trainer a').attrs['href']

    # 馬体重 weight
    result_dic['weight'] = horse_ele.select_one('td.Weight').text.replace('\n', '').split('(')[0]

    # 馬体重の増減 weight_change
    try:
        result_dic['weight_change'] = horse_ele.select_one('td.Weight').text.replace('\n', '').split('(')[1].split(')')[0]
    except:
        print('◆ 注意： "馬体重の増減" の取得に失敗しました')

    # 取得した情報の表示
    #print(list(result_dic.values()))

    return list(result_dic.values())

# %%
# 【出馬表】の１頭分のエレメントから、情報を取得するユーザ関数
def my_result2b(horse_ele):

    # 【出馬表】の辞書
    result_dic = {}

    # 着順 rank
    result_dic['rank'] = ''

    # 枠 waku
    result_dic['waku'] = horse_ele.select('td span')[0].text

    # 馬番 umaban
    result_dic['umaban'] = horse_ele.select('td')[1].text

    # 馬名 bamei
    result_dic['bamei'] = horse_ele.select_one('td span.HorseName a').attrs['title']

    # 馬のURL bamei_url
    result_dic['bamei_url'] = horse_ele.select_one('td span.HorseName a').attrs['href']

    # 性齢 sexage
    result_dic['sexage'] = horse_ele.select_one('td.Barei').text

    # 斤量 handicap
    result_dic['handicap'] = horse_ele.select('td')[5].text

    try:
        # 騎手 jockey
        result_dic['jockey'] = horse_ele.select_one('td.Jockey a').attrs['title']

        # 騎手のURL jockey_url
        result_dic['jockey_url'] = horse_ele.select_one('td.Jockey a').attrs['href']
    except:
        # 騎手 jockey
        result_dic['jockey'] = element.select_one('td.Jockey').text.replace('\n','').replace(' ','')

        # 騎手のURL jockey_url
        result_dic['jockey_url'] = ''

    # タイム racetime
    result_dic['racetime'] = ''

    # 着差 difference
    result_dic['difference'] = ''
    
    # 人気 popular
    result_dic['popular'] = horse_ele.select('td.Popular span')[1].text

    # 単勝オッズ odds
    result_dic['odds'] = horse_ele.select('td.Popular span')[0].text

    # 後3F　furlong3
    result_dic['furlong3'] = ''

    # コーナー通過順 corner_rank
    result_dic['corner_rank'] = ''

    # 厩舎(施設名) stable
    result_dic['stable'] = horse_ele.select_one('td.Trainer span').text

    # 厩舎(調教師) trainer
    result_dic['trainer'] = horse_ele.select_one('td.Trainer a').attrs['title']

    # 厩舎(調教師)のURL trainer_url
    result_dic['trainer_url'] = horse_ele.select_one('td.Trainer a').attrs['href']

    # 馬体重 weight
    result_dic['weight'] = horse_ele.select_one('td.Weight').text.replace('\n', '').split('(')[0]

    # 馬体重の増減 weight_change
    try:
        result_dic['weight_change'] = horse_ele.select_one('td.Weight').text.replace('\n', '').split('(')[1].split(')')[0]
    except:
        result_dic['weight_change'] = ''

    # 取得した情報の表示
    #print(list(result_dic.values()))

    return list(result_dic.values())

# %%
# 出馬表 or 結果・払戻を判定してレースの結果を取得 【 horse_ele > def > list 】
def my_result2(horse_ele, menu):

    # 選択されているサブメニューが "結果・払戻" の場合
    if menu == '結果・払戻':
        return my_result2a(horse_ele)

    # 選択されているサブメニューが "出馬表" の場合
    elif menu == '出馬表':
        return my_result2b(horse_ele)

# %% [markdown]
# ## **メインプログラム**

# %% [markdown]
# ### **①レース開催日の取得**

# %%
# 指定年月URLからレース開催がある年月日を取得
ymd_list = my_get_raceday_from_url()
print(ymd_list)
# Out:
# ['20210904', '20210905', '20210911', '20210912', '20210918', '20210919', '20210920', '20210925', '20210926', '20211002', '20211003']

# %%
ymd_df = pd.DataFrame(ymd_list, columns=['ymd'])
ymd_df
# Out:
#          ymd
# 0   20210904
# 1   20210905
# 2   20210911
# 3   20210912
# 4   20210918
# 5   20210919
# 6   20210920
# 7   20210925
# 8   20210926
# 9   20211002
# 10  20211003

# %%
ymd_df['ymd'].tolist()
# Out:
# ['20210904',
#  '20210905',
#  '20210911',
#  '20210912',
#  '20210918',
#  '20210919',
#  '20210920',
#  '20210925',
#  '20210926',
#  '20211002',
#  '20211003']

# %% [markdown]
# ### **②開催レース一覧**

# %%
# 全レース情報を格納する空のDataFrameを作成
races_df = pd.DataFrame()

# 日を回す d[1:index, 2:d]
for ymd in ymd_list:

    # レース開催日のURLを作成
    url_ymd = 'https://race.netkeiba.com/top/race_list.html?kaisai_date=' + ymd
    print('\n\n①', ymd, url_ymd, '\n')

    # 全ての会場とレースの情報を取得

    # URL（開催日）のソースコードを取得（selenium）
    soup = my_get_source_driver(url_ymd)

    # 特定日の全レース情報を取得
    race_df = my_race_list(soup)

    # データフレームに追加
    races_df = races_df.append(race_df).reset_index(drop=True)
# Out:
# ① 20210904 https://race.netkeiba.com/top/race_list.html?kaisai_date=20210904
#
# ・2021年9月4日(土)　> 1 【新潟】 12 レース
# ['1R', '202104040701', '10:10 ', '3歳以上障害未勝利', '', '13頭', '障2850m', 'https://race.netkeiba.com/race/result.html?race_id=202104040701&rf=race_list']
# ['2R', '202104040702', '10:45 ', '2歳未勝利', '', '15頭', 'ダ1800m', 'https://race.netkeiba.com/race/result.html?race_id=202104040702&rf=race_list']
# ['3R', '202104040703', '11:15 ', '3歳未勝利', '', '15頭', 'ダ1800m', 'https://race.netkeiba.com/race/result.html?race_id=202104040703&rf=race_list']
# ['4R', '202104040704', '11:45 ', '3歳以上障害OP', '5', '11頭', '障3250m', 'https://race.netkeiba.com/race/result.html?race_id=202104040704&rf=race_list']
# ['5R', '202104040705', '12:35 ', '2歳新馬', '', '10頭', '芝2000m', 'https://race.netkeiba.com/race/result.html?race_id=202104040705&rf=race_list']
# ['6R', '202104040706', '13:05 ', '3歳未勝利', '', '18頭', '芝1600m', 'https://race.netkeiba.com/race/result.html?race_id=202104040706&rf=race_list']
# ['2R', '202101020802', '10:25 ', '2歳未勝利', '', '13頭', '芝1500m', 'https://race.netkeiba.com/race/result.html?race_id=202101020802&rf=race_list']
# ['3R', '202101020803', '10:55 ', '3歳未勝利', '', '14頭', 'ダ1700m', 'https://race.netkeiba.com/race/result.html?race_id=202101020803&rf=race_list']
# ['4R', '202101020804', '11:25 ', '3歳未勝利', '', '16頭', '芝1200m', 'https://race.netkeiba.com/race/result.html?race_id=202101020804&rf=race_list']
# ['5R', '202101020805', '12:15 ', '3歳未勝利', '', '14頭', 'ダ1700m', 'https://race.netkeiba.com/race/result.html?race_id=202101020805&rf=race_list']
# ['6R', '202101020806', '12:45 ', '3歳以上1勝クラス', '', '16頭', '芝1200m', 'https://race.netkeiba.com/race/result.html?race_id=202101020806&rf=race_list']
# ['7R', '202101020807', '13:15 ', '3歳以上1勝クラス', '', '14頭', 'ダ1700m', 'https://race.netkeiba.com/race/result.html?race_id=202101020807&rf=race_list']
# ['8R', '202101020808', '13:45 ', '3歳以上1勝クラス', '', '14頭', '芝1800m', 'https://race.netkeiba.com/race/result.html?race_id=202101020808&rf=race_list']
# ['9R', '202101020809', '14:15 ', '3歳以上2勝クラス', '', '14頭', 'ダ1700m', 'https://race.netkeiba.com/race/result.html?race_id=202101020809&rf=race_list']
# ['10R', '202101020810', '14:50 ', 'すずらん賞', '5', '9頭', '芝1200m', 'https://race.netkeiba.com/race/result.html?race_id=202101020810&rf=race_list']
# ['11R', '202101020811', '15:25 ', '丹頂S', '5', '10頭', '芝2600m', 'https://race.netkeiba.com/race/result.html?race_id=202101020811&rf=race_list']
# ['12R', '202101020812', '16:05 ', '釧路湿原特別', '17', '13頭', '芝2000m', 'https://race.netkeiba.com/race/result.html?race_id=202101020812&rf=race_list']
#
#
# ① 20210911 https://race.netkeiba.com/top/race_list.html?kaisai_date=20210911
#
# ・2021年9月11日(土)　> 1 【中山】 12 レース
# ['1R', '202106040101', '10:05 ', '3歳以上障害未勝利', '', '11頭', '障2880m', 'https://race.netkeiba.com/race/result.html?race_id=202106040101&rf=race_list']
# ['2R', '202106040102', '10:40 ', '2歳未勝利', '', '16頭', '芝1600m', 'https://race.netkeiba.com/race/result.html?race_id=202106040102&rf=race_list']
# ['3R', '202106040103', '11:10 ', '2歳未勝利', '', '16頭', 'ダ1800m', 'https://race.netkeiba.com/race/result.html?race_id=202106040103&rf=race_list']
# ['4R', '202106040104', '11:40 ', '2歳新馬', '', '16頭', 'ダ1200m', 'https://race.netkeiba.com/race/result.html?race_id=202106040104&rf=race_list']
# ['5R', '202106040105', '12:30 ', '2歳新馬', '', '12頭', '芝2000m', 'https://race.netkeiba.com/race/result.html?race_id=202106040105&rf=race_list']
# ['6R', '202106040106', '13:00 ', '3歳以上1勝クラス', '', '16頭', 'ダ1200m', 'https://race.netkeiba.com/race/result.html?race_id=202106040106&rf=race_list']
# ['7R', '202106040107', '13:30 ', '3歳以上1勝クラス', '', '13頭', '芝1800m', 'https://race.netkeiba.com/race/result.html?race_id=202106040107&rf=race_list']
# ① 20211002 https://race.netkeiba.com/top/race_list.html?kaisai_date=20211002
#
# ・2021年10月2日(土)　> 1 【中山】 3 レース
# ['9R', '202106040809', ' ', '芙蓉S', '5', '12頭', '芝2000m', 'https://race.netkeiba.com/race/shutuba.html?race_id=202106040809&rf=race_list']
# ['10R', '202106040810', ' ', '勝浦特別', '17', '22頭', '芝1200m', 'https://race.netkeiba.com/race/shutuba.html?race_id=202106040810&rf=race_list']
# ['11R', '202106040811', ' ', '秋風S', '16', '15頭', '芝1600m', 'https://race.netkeiba.com/race/shutuba.html?race_id=202106040811&rf=race_list']
# ・2021年10月2日(土)　> 2 【中京】 3 レース
# ['9R', '202107050809', ' ', 'ききょうS', '5', '9頭', '芝1400m', 'https://race.netkeiba.com/race/shutuba.html?race_id=202107050809&rf=race_list']
# ['10R', '202107050810', ' ', '関ケ原S', '16', '14頭', '芝2000m', 'https://race.netkeiba.com/race/shutuba.html?race_id=202107050810&rf=race_list']
# ['11R', '202107050811', '15:35 ', 'シリウスS', '3', '22頭', 'ダ1900m', 'https://race.netkeiba.com/race/shutuba.html?race_id=202107050811&rf=race_list']
#
#
# ① 20211003 https://race.netkeiba.com/top/race_list.html?kaisai_date=20211003
#
# ・2021年10月3日(日)　> 1 【中山】 4 レース
# ['9R', '202106040909', '14:25 ', 'サフラン賞', '18', '12頭', '芝1600m', 'https://race.netkeiba.com/race/shutuba.html?race_id=202106040909&rf=race_list']
# ['10R', '202106040910', '15:00 ', '茨城新聞杯', '17', '18頭', '芝1800m', 'https://race.netkeiba.com/race/shutuba.html?race_id=202106040910&rf=race_list']
# ['11R', '202106040911', '15:40 ', 'スプリンター', '1', '22頭', '芝1200m', 'https://race.netkeiba.com/race/shutuba.html?race_id=202106040911&rf=race_list']
# ['12R', '202106040912', ' ', '外房S', '16', '35頭', 'ダ1200m', 'https://race.netkeiba.com/race/shutuba.html?race_id=202106040912&rf=race_list']
# ・2021年10月3日(日)　> 2 【中京】 3 レース
# ['9R', '202107050909', ' ', '浜名湖特別', '17', '15頭', '芝2000m', 'https://race.netkeiba.com/race/shutuba.html?race_id=202107050909&rf=race_list']
# ['10R', '202107050910', '14:50 ', '白川郷S', '16', '27頭', 'ダ1900m', 'https://race.netkeiba.com/race/shutuba.html?race_id=202107050910&rf=race_list']
# ['11R', '202107050911', '15:30 ', 'ポートアイS', '15', '27頭', '芝1600m', 'https://race.netkeiba.com/race/shutuba.html?race_id=202107050911&rf=race_list']

# %%
races_df
# Out:
#           ymd  ...                                                url
# 0    20210904  ...  https://race.netkeiba.com/race/result.html?rac...
# 1    20210904  ...  https://race.netkeiba.com/race/result.html?rac...
# 2    20210904  ...  https://race.netkeiba.com/race/result.html?rac...
# 3    20210904  ...  https://race.netkeiba.com/race/result.html?rac...
# 4    20210904  ...  https://race.netkeiba.com/race/result.html?rac...
# ..        ...  ...                                                ...
# 248  20211003  ...  https://race.netkeiba.com/race/shutuba.html?ra...
# 249  20211003  ...  https://race.netkeiba.com/race/shutuba.html?ra...
# 250  20211003  ...  https://race.netkeiba.com/race/shutuba.html?ra...
# 251  20211003  ...  https://race.netkeiba.com/race/shutuba.html?ra...
# 252  20211003  ...  https://race.netkeiba.com/race/shutuba.html?ra...
#
# [253 rows x 11 columns]

# %% [markdown]
# ### **③レース出馬表・結果**

# %%
# ③　レース出馬表・結果

# 全レースの情報のリスト
results1_list = []

# 全レースの結果・払戻のリスト
results2_list = []

# レースを回す df[index, row[数値], row['列名']]
for index, row in races_df.iterrows():

    print('③ {:<5}\t{:<10}\t{:<3}\t{}\t{:<7}\t{:<10}\t\t> '.format(index, row['date'], row['place'], row['grade'], row['r'], row['title']), end='')

    # レースのソースコード取得
    soup = my_request(row['url'])

    # 選択されているサブメニュー（出馬表 / 結果・払戻）
    menu = soup.select_one('ul.RaceMainMenu li a.Active').attrs['title']

    # URLが "結果・払戻" の場合
    if menu == '結果・払戻':

        # レース結果・払戻のトップエレメント
        horse_elements = soup.select('div.ResultTableWrap tr.HorseList')

    # URLが "出馬表" の場合
    elif menu == '出馬表':

        # レースのソースコード取得
        soup = my_get_source_driver(row['url'])

        # レース出馬表のトップエレメント
        horse_elements = soup.select('div.RaceTableArea tr.HorseList')

    # 1. レースの情報を取得　（1レース） ★
    result1_list = my_result1(soup)
    print(result1_list, row['url'])

    # 1. 全レースの情報のリストに追加
    results1_list.append([row['ymd']] + result1_list + [row['grade'], row['race_id'], row['url']])

    # 2. レースの結果・払戻を取得 （1レース）

    # 全馬のレース結果・払戻を取得
    for i, element in enumerate(horse_elements):

        # レース結果・払戻を取得 （1頭） ★
        result2_list = my_result2(element, menu)

        # 取得したレース結果（1頭分）の表示
        #print('\t#{}\t> {}'.format(i+1, result2_list))

        # 2. 全レースの結果・払戻のリストに追加　（完走馬のみ）
        if type(result2_list) == list:
            results2_list.append(result2_list + [row['race_id']])

    # 2. レースの結果・払戻を取得完了 （1レース） ★
    print('')

# ③-1. 全レースの情報のDataFrame
columns1 = ['ymd', 'date', 'menu', 'place', 'r', 'title', 'start_time', 'distance', 'race_type', 'number', 'prize', 'weather', 'course_status', 'grade', 'race_id', 'url']
results1_df = pd.DataFrame(results1_list, index=None, columns=columns1)

# ③-2. 全レースの結果・払戻のDataFrame
columns2 = ['rank', 'waku', 'umaban', 'bamei', 'bamei_url', 'sexage', 'handicap', 'jockey', 'jockey_url', 'racetime', 'difference', 'popular', 'odds', 'furlong3', 'corner_rank', 'stable', 'trainer', 'trainer_url', 'weight', 'weight_change', 'race_id']
results2_df = pd.DataFrame(results2_list, index=None, columns=columns2)
# Out:
# ③ 0    	9月4日(土)   	新潟 		1R     	3歳以上障害未勝利 		> ['9月4日(土)', '結果・払戻', '新潟', '1R', '3歳以上障害未勝利', '10:10', ' 障2850m', '障害３歳以上', '13頭', '79032020012079', '曇', '稍'] https://race.netkeiba.com/race/result.html?race_id=202104040701&rf=race_list
#
# ③ 1    	9月4日(土)   	新潟 		2R     	2歳未勝利     		> ['9月4日(土)', '結果・払戻', '新潟', '2R', '2歳未勝利', '10:45', ' ダ1800m', 'サラ系２歳', '15頭', '5102001307751', '曇', '稍'] https://race.netkeiba.com/race/result.html?race_id=202104040702&rf=race_list
#
# ③ 2    	9月4日(土)   	新潟 		3R     	3歳未勝利     		> ['9月4日(土)', '結果・払戻', '新潟', '3R', '3歳未勝利', '11:15', ' ダ1800m', 'サラ系３歳', '15頭', '5102001307751', '小雨', '稍'] https://race.netkeiba.com/race/result.html?race_id=202104040703&rf=race_list
#
# ③ 3    	9月4日(土)   	新潟 	5	4R     	3歳以上障害OP  		> ['9月4日(土)', '結果・払戻', '新潟', '4R', '3歳以上障害OP', '11:45', ' 障3250m', '障害３歳以上', '11頭', '1350540340200135', '曇', '稍'] https://race.netkeiba.com/race/result.html?race_id=202104040704&rf=race_list
#
# ③ 4    	9月4日(土)   	新潟 		5R     	2歳新馬      		> ['9月4日(土)', '結果・払戻', '新潟', '5R', '2歳新馬', '12:35', ' 芝2000m', 'サラ系２歳', '10頭', '70028018011070', '曇', '稍'] https://race.netkeiba.com/race/result.html?race_id=202104040705&rf=race_list
#
# ③ 5    	9月4日(土)   	新潟 		6R     	3歳未勝利     		> ['9月4日(土)', '結果・払戻', '新潟', '6R', '3歳未勝利', '13:05', ' 芝1600m', 'サラ系３歳', '18頭', '5102001307751', '曇', '稍'] https://race.netkeiba.com/race/result.html?race_id=202104040706&rf=race_list
#
# ③ 6    	9月4日(土)   	新潟 		7R     	3歳未勝利     		> ['9月4日(土)', '結果・払戻', '新潟', '7R', '3歳未勝利', '13:35', ' 芝1800m', 'サラ系３歳', '18頭', '5102001307751', '雨', '稍'] https://race.netkeiba.com/race/result.html?race_id=202104040707&rf=race_list
#
# ③ 7    	9月4日(土)   	新潟 		8R     	3歳以上1勝クラス 		> ['9月4日(土)', '結果・払戻', '新潟', '8R', '3歳以上1勝クラス', '14:05', ' ダ1200m', 'サラ系３歳以上', '15頭', '76030019011076', '雨', '稍'] https://race.netkeiba.com/race/result.html?race_id=202104040708&rf=race_list
#
# ③ 8    	9月4日(土)   	新潟 	18	9R     	瓢湖特別      		> ['9月4日(土)', '結果・払戻', '新潟', '9R', '瓢湖特別', '14:36', ' 芝2200m', 'サラ系３歳以上', '12頭', '1060420270160106', '雨', '稍'] https://race.netkeiba.com/race/result.html?race_id=202104040709&rf=race_list
#
# ③ 9    	9月4日(土)   	新潟 	17	10R    	赤倉特別      		> ['9月4日(土)', '結果・払戻', '新潟', '10R', '赤倉特別', '15:11', ' 芝2000m', 'サラ系３歳以上', '13頭', '1500600380230150', '曇', '稍'] https://race.netkeiba.com/race/result.html?race_id=202104040710&rf=race_list
#
# ③ 10   	9月4日(土)   	新潟 	16	11R    	古町S       		> ['9月4日(土)', '結果・払戻', '新潟', '11R', '古町S', '15:45', ' ダ1800m', 'サラ系３歳以上', '15頭', '1820730460270182', '曇', '稍'] https://race.netkeiba.com/race/result.html?race_id=202104040711&rf=race_list
#
# ③ 11   	9月4日(土)   	新潟 		12R    	3歳以上1勝クラス 		> ['9月4日(土)', '結果・払戻', '新潟', '12R', '3歳以上1勝クラス', '16:30', ' 芝1600m', 'サラ系３歳以上', '18頭', '76030019011076', '曇', '稍'] https://race.netkeiba.com/race/result.html?race_id=202104040712&rf=race_list
#
# ③ 12   	9月4日(土)   	小倉 		1R     	2歳未勝利     		> ['9月4日(土)', '結果・払戻', '小倉', '1R', '2歳未勝利', '10:01', ' 芝1800m', 'サラ系２歳', '14頭', '5102001307751', '曇', '重'] https://race.netkeiba.com/race/result.html?race_id=202110040701&rf=race_list
#
# ③ 13   	9月4日(土)   	小倉 		2R     	2歳未勝利     		> ['9月4日(土)', '結果・払戻', '小倉', '2R', '2歳未勝利', '10:35', ' ダ1700m', 'サラ系２歳', '16頭', '5102001307751', '曇', '不'] https://race.netkeiba.com/race/result.html?race_id=202110040702&rf=race_list
#
# ③ 14   	9月4日(土)   	小倉 		3R     	3歳未勝利     		> ['9月4日(土)', '結果・払戻', '小倉', '3R', '3歳未勝利', '11:05', ' 芝1200m', 'サラ系３歳', '18頭', '5102001307751', '曇', '重'] https://race.netkeiba.com/race/result.html?race_id=202110040703&rf=race_list
#
# ③ 15   	9月4日(土)   	小倉 		4R     	3歳未勝利     		> ['9月4日(土)', '結果・払戻', '小倉', '4R', '3歳未勝利', '11:35', ' 芝2000m', 'サラ系３歳', '18頭', '5102001307751', '曇', '重'] https://race.netkeiba.com/race/result.html?race_id=202110040704&rf=race_list
#
# ③ 16   	9月4日(土)   	小倉 		5R     	2歳新馬      		> ['9月4日(土)', '結果・払戻', '小倉', '5R', '2歳新馬', '12:25', ' 芝1200m', 'サラ系２歳', '13頭', '70028018011070', '曇', '稍'] https://race.netkeiba.com/race/result.html?race_id=202110040705&rf=race_list
#
# ③ 17   	9月4日(土)   	小倉 		6R     	3歳未勝利     		> ['9月4日(土)', '結果・払戻', '小倉', '6R', '3歳未勝利', '12:55', ' ダ1000m', 'サラ系３歳', '14頭', '5102001307751', '曇', '重'] https://race.netkeiba.com/race/result.html?race_id=202110040706&rf=race_list
#
# ③ 18   	9月4日(土)   	小倉 		7R     	3歳以上1勝クラス 		> ['9月4日(土)', '結果・払戻', '小倉', '7R', '3歳以上1勝クラス', '13:25', ' 芝1200m', 'サラ系３歳以上', '15頭', '76030019011076', '曇', '稍'] https://race.netkeiba.com/race/result.html?race_id=202110040707&rf=race_list
#
# ③ 19   	9月4日(土)   	小倉 		8R     	3歳以上1勝クラス 		> ['9月4日(土)', '結果・払戻', '小倉', '8R', '3歳以上1勝クラス', '13:55', ' 芝1800m', 'サラ系３歳以上', '11頭', '76030019011076', '曇', '稍'] https://race.netkeiba.com/race/result.html?race_id=202110040708&rf=race_list
#
# ③ 20   	9月4日(土)   	小倉 	17	9R     	別府特別      		> ['9月4日(土)', '結果・払戻', '小倉', '9R', '別府特別', '14:25', ' 芝1200m', 'サラ系３歳以上', '18頭', '1500600380230150', '曇', '稍'] https://race.netkeiba.com/race/result.html?race_id=202110040709&rf=race_list
#
# ③ 21   	9月4日(土)   	小倉 	17	10R    	天草特別      		> ['9月4日(土)', '結果・払戻', '小倉', '10R', '天草特別', '15:01', ' ダ1700m', 'サラ系３歳以上', '16頭', '1500600380230150', '曇', '重'] https://race.netkeiba.com/race/result.html?race_id=202110040710&rf=race_list
#
# ③ 22   	9月4日(土)   	小倉 	16	11R    	テレQ杯      		> ['9月4日(土)', '結果・払戻', '小倉', '11R', 'テレQ杯', '15:35', ' 芝1200m', 'サラ系３歳以上', '12頭', '1820730460270182', '曇', '稍'] https://race.netkeiba.com/race/result.html?race_id=202110040711&rf=race_list
#
# ③ 23   	9月4日(土)   	小倉 		12R    	3歳以上1勝クラス 		> ['9月4日(土)', '結果・払戻', '小倉', '12R', '3歳以上1勝クラス', '16:15', ' ダ1700m', 'サラ系３歳以上', '16頭', '76030019011076', '曇', '重'] https://race.netkeiba.com/race/result.html?race_id=202110040712&rf=race_list
#
# ③ 24   	9月4日(土)   	札幌 		1R     	2歳未勝利     		> ['9月4日(土)', '結果・払戻', '札幌', '1R', '2歳未勝利', '09:50', ' 芝1200m', 'サラ系２歳', '9頭', '5102001307751', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202101020701&rf=race_list
#
# ③ 25   	9月4日(土)   	札幌 		2R     	2歳未勝利     		> ['9月4日(土)', '結果・払戻', '札幌', '2R', '2歳未勝利', '10:25', ' ダ1700m', 'サラ系２歳', '12頭', '5102001307751', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202101020702&rf=race_list
#
# ③ 26   	9月4日(土)   	札幌 		3R     	3歳未勝利     		> ['9月4日(土)', '結果・払戻', '札幌', '3R', '3歳未勝利', '10:55', ' 芝2000m', 'サラ系３歳', '16頭', '5102001307751', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202101020703&rf=race_list
#
# ③ 27   	9月4日(土)   	札幌 		4R     	3歳未勝利     		> ['9月4日(土)', '結果・払戻', '札幌', '4R', '3歳未勝利', '11:25', ' ダ1700m', 'サラ系３歳', '14頭', '5102001307751', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202101020704&rf=race_list
#
# ③ 28   	9月4日(土)   	札幌 		5R     	2歳新馬      		> ['9月4日(土)', '結果・払戻', '札幌', '5R', '2歳新馬', '12:15', ' 芝1500m', 'サラ系２歳', '12頭', '70028018011070', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202101020705&rf=race_list
#
# ③ 29   	9月4日(土)   	札幌 		6R     	3歳以上1勝クラス 		> ['9月4日(土)', '結果・払戻', '札幌', '6R', '3歳以上1勝クラス', '12:45', ' ダ1700m', 'サラ系３歳以上', '14頭', '76030019011076', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202101020706&rf=race_list
#
# ③ 30   	9月4日(土)   	札幌 		7R     	3歳以上1勝クラス 		> ['9月4日(土)', '結果・払戻', '札幌', '7R', '3歳以上1勝クラス', '13:15', ' ダ1000m', 'サラ系３歳以上', '12頭', '76030019011076', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202101020707&rf=race_list
#
# ③ 31   	9月4日(土)   	札幌 		8R     	3歳以上1勝クラス 		> ['9月4日(土)', '結果・払戻', '札幌', '8R', '3歳以上1勝クラス', '13:45', ' 芝2000m', 'サラ系３歳以上', '16頭', '76030019011076', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202101020708&rf=race_list
#
# ③ 32   	9月4日(土)   	札幌 		9R     	3歳以上1勝クラス 		> ['9月4日(土)', '結果・払戻', '札幌', '9R', '3歳以上1勝クラス', '14:15', ' ダ1700m', 'サラ系３歳以上', '14頭', '76030019011076', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202101020709&rf=race_list
#
# ③ 33   	9月4日(土)   	札幌 	17	10R    	札幌スポニチ    		> ['9月4日(土)', '結果・払戻', '札幌', '10R', '札幌スポニチ賞', '14:50', ' 芝1200m', 'サラ系３歳以上', '16頭', '1500600380230150', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202101020710&rf=race_list
#
# ③ 34   	9月4日(土)   	札幌 	3	11R    	札幌2歳S     		> ['9月4日(土)', '結果・払戻', '札幌', '11R', '札幌2歳S', '15:25', ' 芝1800m', 'サラ系２歳', '10頭', '31001200780470310', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202101020711&rf=race_list
#
# ③ 35   	9月4日(土)   	札幌 	16	12R    	日高S       		> ['9月4日(土)', '結果・払戻', '札幌', '12R', '日高S', '16:05', ' 芝1500m', 'サラ系３歳以上', '14頭', '1820730460270182', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202101020712&rf=race_list
#
# ③ 36   	9月5日(日)   	新潟 		1R     	2歳未勝利     		> ['9月5日(日)', '結果・払戻', '新潟', '1R', '2歳未勝利', '10:10', ' 芝1200m', 'サラ系２歳', '17頭', '5102001307751', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202104040801&rf=race_list
#
# ③ 37   	9月5日(日)   	新潟 		2R     	2歳未勝利     		> ['9月5日(日)', '結果・払戻', '新潟', '2R', '2歳未勝利', '10:45', ' 芝2000m', 'サラ系２歳', '10頭', '5102001307751', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202104040802&rf=race_list
#
# ③ 38   	9月5日(日)   	新潟 		3R     	3歳未勝利     		> ['9月5日(日)', '結果・払戻', '新潟', '3R', '3歳未勝利', '11:15', ' ダ1800m', 'サラ系３歳', '15頭', '5102001307751', '曇', '稍'] https://race.netkeiba.com/race/result.html?race_id=202104040803&rf=race_list
#
# ③ 39   	9月5日(日)   	新潟 		4R     	3歳未勝利     		> ['9月5日(日)', '結果・払戻', '新潟', '4R', '3歳未勝利', '11:45', ' 芝2200m', 'サラ系３歳', '18頭', '5102001307751', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202104040804&rf=race_list
#
# ③ 40   	9月5日(日)   	新潟 		5R     	2歳新馬      		> ['9月5日(日)', '結果・払戻', '新潟', '5R', '2歳新馬', '12:35', ' 芝1800m', 'サラ系２歳', '10頭', '70028018011070', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202104040805&rf=race_list
#
# ③ 41   	9月5日(日)   	新潟 		6R     	2歳新馬      		> ['9月5日(日)', '結果・払戻', '新潟', '6R', '2歳新馬', '13:05', ' 芝1400m', 'サラ系２歳', '18頭', '70028018011070', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202104040806&rf=race_list
#
# ③ 42   	9月5日(日)   	新潟 		7R     	3歳未勝利     		> ['9月5日(日)', '結果・払戻', '新潟', '7R', '3歳未勝利', '13:35', ' ダ1200m', 'サラ系３歳', '15頭', '5102001307751', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202104040807&rf=race_list
#
# ③ 43   	9月5日(日)   	新潟 		8R     	3歳以上1勝クラス 		> ['9月5日(日)', '結果・払戻', '新潟', '8R', '3歳以上1勝クラス', '14:05', ' ダ1800m', 'サラ系３歳以上', '15頭', '76030019011076', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202104040808&rf=race_list
#
# ③ 44   	9月5日(日)   	新潟 	17	9R     	飯豊特別      		> ['9月5日(日)', '結果・払戻', '新潟', '9R', '飯豊特別', '14:36', ' 芝1200m', 'サラ系３歳以上', '14頭', '1500600380230150', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202104040809&rf=race_list
#
# ③ 45   	9月5日(日)   	新潟 	17	10R    	両津湾特別     		> ['9月5日(日)', '結果・払戻', '新潟', '10R', '両津湾特別', '15:11', ' ダ1800m', 'サラ系３歳以上', '15頭', '1500600380230150', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202104040810&rf=race_list
#
# ③ 46   	9月5日(日)   	新潟 	3	11R    	新潟記念      		> ['9月5日(日)', '結果・払戻', '新潟', '11R', '新潟記念', '15:45', ' 芝2000m', 'サラ系３歳以上', '17頭', '410016001000620410', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202104040811&rf=race_list
#
# ③ 47   	9月5日(日)   	新潟 	18	12R    	雷光特別      		> ['9月5日(日)', '結果・払戻', '新潟', '12R', '雷光特別', '16:30', ' 芝1000m', 'サラ系３歳以上', '17頭', '1060420270160106', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202104040812&rf=race_list
#
# ③ 48   	9月5日(日)   	小倉 		1R     	3歳以上障害未勝利 		> ['9月5日(日)', '結果・払戻', '小倉', '1R', '3歳以上障害未勝利', '10:01', ' 障2860m', '障害３歳以上', '10頭', '79032020012079', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202110040801&rf=race_list
#
# ③ 49   	9月5日(日)   	小倉 		2R     	2歳未勝利     		> ['9月5日(日)', '結果・払戻', '小倉', '2R', '2歳未勝利', '10:35', ' 芝1200m', 'サラ系２歳', '13頭', '5102001307751', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202110040802&rf=race_list
#
# ③ 50   	9月5日(日)   	小倉 		3R     	3歳未勝利     		> ['9月5日(日)', '結果・払戻', '小倉', '3R', '3歳未勝利', '11:05', ' ダ1700m', 'サラ系３歳', '16頭', '5102001307751', '晴', '稍'] https://race.netkeiba.com/race/result.html?race_id=202110040803&rf=race_list
#
# ③ 51   	9月5日(日)   	小倉 		4R     	3歳未勝利     		> ['9月5日(日)', '結果・払戻', '小倉', '4R', '3歳未勝利', '11:35', ' 芝2000m', 'サラ系３歳', '18頭', '5102001307751', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202110040804&rf=race_list
#
# ③ 52   	9月5日(日)   	小倉 		5R     	2歳新馬      		> ['9月5日(日)', '結果・払戻', '小倉', '5R', '2歳新馬', '12:25', ' 芝1800m', 'サラ系２歳', '13頭', '70028018011070', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202110040805&rf=race_list
#
# ③ 53   	9月5日(日)   	小倉 		6R     	3歳未勝利     		> ['9月5日(日)', '結果・払戻', '小倉', '6R', '3歳未勝利', '12:55', ' ダ1700m', 'サラ系３歳', '16頭', '5102001307751', '曇', '稍'] https://race.netkeiba.com/race/result.html?race_id=202110040806&rf=race_list
#
# ③ 54   	9月5日(日)   	小倉 		7R     	3歳以上1勝クラス 		> ['9月5日(日)', '結果・払戻', '小倉', '7R', '3歳以上1勝クラス', '13:25', ' 芝1200m', 'サラ系３歳以上', '11頭', '76030019011076', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202110040807&rf=race_list
#
# ③ 55   	9月5日(日)   	小倉 		8R     	3歳以上1勝クラス 		> ['9月5日(日)', '結果・払戻', '小倉', '8R', '3歳以上1勝クラス', '13:55', ' ダ1000m', 'サラ系３歳以上', '13頭', '76030019011076', '曇', '稍'] https://race.netkeiba.com/race/result.html?race_id=202110040808&rf=race_list
#
# ③ 56   	9月5日(日)   	小倉 	17	9R     	筑後川特別     		> ['9月5日(日)', '結果・払戻', '小倉', '9R', '筑後川特別', '14:25', ' 芝1800m', 'サラ系３歳以上', '11頭', '1500600380230150', '小雨', '良'] https://race.netkeiba.com/race/result.html?race_id=202110040809&rf=race_list
#
# ③ 57   	9月5日(日)   	小倉 	16	10R    	西日本スポ杯    		> ['9月5日(日)', '結果・払戻', '小倉', '10R', '西日本スポーツ杯', '15:01', ' ダ1700m', 'サラ系３歳以上', '16頭', '1820730460270182', '小雨', '稍'] https://race.netkeiba.com/race/result.html?race_id=202110040810&rf=race_list
#
# ③ 58   	9月5日(日)   	小倉 	3	11R    	小倉2歳S     		> ['9月5日(日)', '結果・払戻', '小倉', '11R', '小倉2歳S', '15:35', ' 芝1200m', 'サラ系２歳', '10頭', '31001200780470310', '小雨', '良'] https://race.netkeiba.com/race/result.html?race_id=202110040811&rf=race_list
#
# ③ 59   	9月5日(日)   	小倉 		12R    	3歳以上1勝クラス 		> ['9月5日(日)', '結果・払戻', '小倉', '12R', '3歳以上1勝クラス', '16:15', ' 芝2600m', 'サラ系３歳以上', '11頭', '76030019011076', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202110040812&rf=race_list
#
# ③ 60   	9月5日(日)   	札幌 		1R     	2歳未勝利     		> ['9月5日(日)', '結果・払戻', '札幌', '1R', '2歳未勝利', '09:50', ' 芝2000m', 'サラ系２歳', '11頭', '5102001307751', '晴', '稍'] https://race.netkeiba.com/race/result.html?race_id=202101020801&rf=race_list
#
# ③ 61   	9月5日(日)   	札幌 		2R     	2歳未勝利     		> ['9月5日(日)', '結果・払戻', '札幌', '2R', '2歳未勝利', '10:25', ' 芝1500m', 'サラ系２歳', '13頭', '5102001307751', '晴', '稍'] https://race.netkeiba.com/race/result.html?race_id=202101020802&rf=race_list
#
# ③ 62   	9月5日(日)   	札幌 		3R     	3歳未勝利     		> ['9月5日(日)', '結果・払戻', '札幌', '3R', '3歳未勝利', '10:55', ' ダ1700m', 'サラ系３歳', '14頭', '5102001307751', '晴', '稍'] https://race.netkeiba.com/race/result.html?race_id=202101020803&rf=race_list
#
# ③ 63   	9月5日(日)   	札幌 		4R     	3歳未勝利     		> ['9月5日(日)', '結果・払戻', '札幌', '4R', '3歳未勝利', '11:25', ' 芝1200m', 'サラ系３歳', '16頭', '5102001307751', '晴', '稍'] https://race.netkeiba.com/race/result.html?race_id=202101020804&rf=race_list
#
# ③ 64   	9月5日(日)   	札幌 		5R     	3歳未勝利     		> ['9月5日(日)', '結果・払戻', '札幌', '5R', '3歳未勝利', '12:15', ' ダ1700m', 'サラ系３歳', '14頭', '5102001307751', '晴', '稍'] https://race.netkeiba.com/race/result.html?race_id=202101020805&rf=race_list
#
# ③ 65   	9月5日(日)   	札幌 		6R     	3歳以上1勝クラス 		> ['9月5日(日)', '結果・払戻', '札幌', '6R', '3歳以上1勝クラス', '12:45', ' 芝1200m', 'サラ系３歳以上', '16頭', '76030019011076', '晴', '稍'] https://race.netkeiba.com/race/result.html?race_id=202101020806&rf=race_list
#
# ③ 66   	9月5日(日)   	札幌 		7R     	3歳以上1勝クラス 		> ['9月5日(日)', '結果・払戻', '札幌', '7R', '3歳以上1勝クラス', '13:15', ' ダ1700m', 'サラ系３歳以上', '14頭', '76030019011076', '晴', '稍'] https://race.netkeiba.com/race/result.html?race_id=202101020807&rf=race_list
#
# ③ 67   	9月5日(日)   	札幌 		8R     	3歳以上1勝クラス 		> ['9月5日(日)', '結果・払戻', '札幌', '8R', '3歳以上1勝クラス', '13:45', ' 芝1800m', 'サラ系３歳以上', '14頭', '76030019011076', '晴', '稍'] https://race.netkeiba.com/race/result.html?race_id=202101020808&rf=race_list
#
# ③ 68   	9月5日(日)   	札幌 		9R     	3歳以上2勝クラス 		> ['9月5日(日)', '結果・払戻', '札幌', '9R', '3歳以上2勝クラス', '14:15', ' ダ1700m', 'サラ系３歳以上', '14頭', '1100440280170110', '晴', '稍'] https://race.netkeiba.com/race/result.html?race_id=202101020809&rf=race_list
#
# ③ 69   	9月5日(日)   	札幌 	5	10R    	すずらん賞     		> ['9月5日(日)', '結果・払戻', '札幌', '10R', 'すずらん賞', '14:50', ' 芝1200m', 'サラ系２歳', '9頭', '1600640400240160', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202101020810&rf=race_list
#
# ③ 70   	9月5日(日)   	札幌 	5	11R    	丹頂S       		> ['9月5日(日)', '結果・払戻', '札幌', '11R', '丹頂S', '15:25', ' 芝2600m', 'サラ系３歳以上', '10頭', '2400960600360240', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202101020811&rf=race_list
#
# ③ 71   	9月5日(日)   	札幌 	17	12R    	釧路湿原特別    		> ['9月5日(日)', '結果・払戻', '札幌', '12R', '釧路湿原特別', '16:05', ' 芝2000m', 'サラ系３歳以上', '13頭', '1500600380230150', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202101020812&rf=race_list
#
# ③ 72   	9月11日(土)  	中山 		1R     	3歳以上障害未勝利 		> ['9月11日(土)', '結果・払戻', '中山', '1R', '3歳以上障害未勝利', '10:05', ' 障2880m', '障害３歳以上', '11頭', '79032020012079', '曇', '稍'] https://race.netkeiba.com/race/result.html?race_id=202106040101&rf=race_list
#
# ③ 73   	9月11日(土)  	中山 		2R     	2歳未勝利     		> ['9月11日(土)', '結果・払戻', '中山', '2R', '2歳未勝利', '10:40', ' 芝1600m', 'サラ系２歳', '16頭', '5102001307751', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040102&rf=race_list
#
# ③ 74   	9月11日(土)  	中山 		3R     	2歳未勝利     		> ['9月11日(土)', '結果・払戻', '中山', '3R', '2歳未勝利', '11:10', ' ダ1800m', 'サラ系２歳', '16頭', '5102001307751', '曇', '稍'] https://race.netkeiba.com/race/result.html?race_id=202106040103&rf=race_list
#
# ③ 75   	9月11日(土)  	中山 		4R     	2歳新馬      		> ['9月11日(土)', '結果・払戻', '中山', '4R', '2歳新馬', '11:40', ' ダ1200m', 'サラ系２歳', '16頭', '70028018011070', '曇', '稍'] https://race.netkeiba.com/race/result.html?race_id=202106040104&rf=race_list
#
# ③ 76   	9月11日(土)  	中山 		5R     	2歳新馬      		> ['9月11日(土)', '結果・払戻', '中山', '5R', '2歳新馬', '12:30', ' 芝2000m', 'サラ系２歳', '12頭', '70028018011070', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040105&rf=race_list
#
# ③ 77   	9月11日(土)  	中山 		6R     	3歳以上1勝クラス 		> ['9月11日(土)', '結果・払戻', '中山', '6R', '3歳以上1勝クラス', '13:00', ' ダ1200m', 'サラ系３歳以上', '16頭', '76030019011076', '曇', '稍'] https://race.netkeiba.com/race/result.html?race_id=202106040106&rf=race_list
#
# ③ 78   	9月11日(土)  	中山 		7R     	3歳以上1勝クラス 		> ['9月11日(土)', '結果・払戻', '中山', '7R', '3歳以上1勝クラス', '13:30', ' 芝1800m', 'サラ系３歳以上', '13頭', '76030019011076', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040107&rf=race_list
#
# ③ 79   	9月11日(土)  	中山 		8R     	3歳以上1勝クラス 		> ['9月11日(土)', '結果・払戻', '中山', '8R', '3歳以上1勝クラス', '14:01', ' ダ1800m', 'サラ系３歳以上', '16頭', '76030019011076', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040108&rf=race_list
#
# ③ 80   	9月11日(土)  	中山 	18	9R     	アスター賞     		> ['9月11日(土)', '結果・払戻', '中山', '9R', 'アスター賞', '14:35', ' 芝1600m', 'サラ系２歳', '8頭', '1010400250150101', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040109&rf=race_list
#
# ③ 81   	9月11日(土)  	中山 	17	10R    	汐留特別      		> ['9月11日(土)', '結果・払戻', '中山', '10R', '汐留特別', '15:10', ' 芝1200m', 'サラ系３歳以上', '10頭', '1500600380230150', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040110&rf=race_list
#
# ③ 82   	9月11日(土)  	中山 	3	11R    	紫苑S       		> ['9月11日(土)', '結果・払戻', '中山', '11R', '紫苑S', '15:45', ' 芝2000m', 'サラ系３歳', '18頭', '35001400880530350', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040111&rf=race_list
#
# ③ 83   	9月11日(土)  	中山 		12R    	3歳以上1勝クラス 		> ['9月11日(土)', '結果・払戻', '中山', '12R', '3歳以上1勝クラス', '16:25', ' ダ1200m', 'サラ系３歳以上', '16頭', '76030019011076', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040112&rf=race_list
#
# ③ 84   	9月11日(土)  	中京 		1R     	2歳未勝利     		> ['9月11日(土)', '結果・払戻', '中京', '1R', '2歳未勝利', '09:50', ' ダ1200m', 'サラ系２歳', '7頭', '5102001307751', '曇', '稍'] https://race.netkeiba.com/race/result.html?race_id=202107050101&rf=race_list
#
# ③ 85   	9月11日(土)  	中京 		2R     	2歳未勝利     		> ['9月11日(土)', '結果・払戻', '中京', '2R', '2歳未勝利', '10:25', ' ダ1800m', 'サラ系２歳', '12頭', '5102001307751', '曇', '稍'] https://race.netkeiba.com/race/result.html?race_id=202107050102&rf=race_list
#
# ③ 86   	9月11日(土)  	中京 		3R     	2歳未勝利     		> ['9月11日(土)', '結果・払戻', '中京', '3R', '2歳未勝利', '10:55', ' 芝2000m', 'サラ系２歳', '9頭', '5102001307751', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202107050103&rf=race_list
#
# ③ 87   	9月11日(土)  	中京 		4R     	2歳新馬      		> ['9月11日(土)', '結果・払戻', '中京', '4R', '2歳新馬', '11:25', ' 芝1600m', 'サラ系２歳', '10頭', '70028018011070', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202107050104&rf=race_list
#
# ③ 88   	9月11日(土)  	中京 		5R     	2歳新馬      		> ['9月11日(土)', '結果・払戻', '中京', '5R', '2歳新馬', '12:15', ' 芝1400m', 'サラ系２歳', '12頭', '70028018011070', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202107050105&rf=race_list
#
# ③ 89   	9月11日(土)  	中京 		6R     	3歳以上1勝クラス 		> ['9月11日(土)', '結果・払戻', '中京', '6R', '3歳以上1勝クラス', '12:45', ' ダ1900m', 'サラ系３歳以上', '12頭', '76030019011076', '晴', '稍'] https://race.netkeiba.com/race/result.html?race_id=202107050106&rf=race_list
#
# ③ 90   	9月11日(土)  	中京 		7R     	3歳以上1勝クラス 		> ['9月11日(土)', '結果・払戻', '中京', '7R', '3歳以上1勝クラス', '13:15', ' ダ1400m', 'サラ系３歳以上', '12頭', '76030019011076', '晴', '稍'] https://race.netkeiba.com/race/result.html?race_id=202107050107&rf=race_list
#
# ③ 91   	9月11日(土)  	中京 		8R     	3歳以上1勝クラス 		> ['9月11日(土)', '結果・払戻', '中京', '8R', '3歳以上1勝クラス', '13:50', ' 芝2000m', 'サラ系３歳以上', '13頭', '76030019011076', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202107050108&rf=race_list
#
# ③ 92   	9月11日(土)  	中京 	17	9R     	日進特別      		> ['9月11日(土)', '結果・払戻', '中京', '9R', '日進特別', '14:25', ' ダ1800m', 'サラ系３歳以上', '11頭', '1500600380230150', '曇', '稍'] https://race.netkeiba.com/race/result.html?race_id=202107050109&rf=race_list
#
# ③ 93   	9月11日(土)  	中京 	16	10R    	ムーンライト    		> ['9月11日(土)', '結果・払戻', '中京', '10R', 'ムーンライトHC', '15:01', ' 芝2200m', 'サラ系３歳以上', '13頭', '1820730460270182', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202107050110&rf=race_list
#
# ③ 94   	9月11日(土)  	中京 	15	11R    	エニフS      		> ['9月11日(土)', '結果・払戻', '中京', '11R', 'エニフS', '15:35', ' ダ1400m', 'サラ系３歳以上', '16頭', '2300920580350230', '曇', '稍'] https://race.netkeiba.com/race/result.html?race_id=202107050111&rf=race_list
#
# ③ 95   	9月11日(土)  	中京 		12R    	3歳以上2勝クラス 		> ['9月11日(土)', '結果・払戻', '中京', '12R', '3歳以上2勝クラス', '16:10', ' ダ1200m', 'サラ系３歳以上', '16頭', '1100440280170110', '曇', '稍'] https://race.netkeiba.com/race/result.html?race_id=202107050112&rf=race_list
#
# ③ 96   	9月12日(日)  	中山 		1R     	2歳未勝利     		> ['9月12日(日)', '結果・払戻', '中山', '1R', '2歳未勝利', '10:05', ' ダ1200m', 'サラ系２歳', '16頭', '5102001307751', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040201&rf=race_list
#
# ③ 97   	9月12日(日)  	中山 		2R     	2歳未勝利     		> ['9月12日(日)', '結果・払戻', '中山', '2R', '2歳未勝利', '10:35', ' 芝2000m', 'サラ系２歳', '10頭', '5102001307751', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040202&rf=race_list
#
# ③ 98   	9月12日(日)  	中山 		3R     	2歳新馬      		> ['9月12日(日)', '結果・払戻', '中山', '3R', '2歳新馬', '11:05', ' ダ1800m', 'サラ系２歳', '16頭', '70028018011070', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040203&rf=race_list
#
# ③ 99   	9月12日(日)  	中山 		4R     	3歳以上1勝クラス 		> ['9月12日(日)', '結果・払戻', '中山', '4R', '3歳以上1勝クラス', '11:35', ' ダ1200m', 'サラ系３歳以上', '16頭', '76030019011076', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040204&rf=race_list
#
# ③ 100  	9月12日(日)  	中山 		5R     	2歳新馬      		> ['9月12日(日)', '結果・払戻', '中山', '5R', '2歳新馬', '12:25', ' 芝1600m', 'サラ系２歳', '16頭', '70028018011070', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040205&rf=race_list
#
# ③ 101  	9月12日(日)  	中山 		6R     	3歳以上1勝クラス 		> ['9月12日(日)', '結果・払戻', '中山', '6R', '3歳以上1勝クラス', '12:55', ' ダ1800m', 'サラ系３歳以上', '13頭', '76030019011076', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040206&rf=race_list
#
# ③ 102  	9月12日(日)  	中山 		7R     	3歳以上1勝クラス 		> ['9月12日(日)', '結果・払戻', '中山', '7R', '3歳以上1勝クラス', '13:25', ' 芝1600m', 'サラ系３歳以上', '14頭', '76030019011076', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040207&rf=race_list
#
# ③ 103  	9月12日(日)  	中山 	17	8R     	白井特別      		> ['9月12日(日)', '結果・払戻', '中山', '8R', '白井特別', '14:01', ' 芝1800m', 'サラ系３歳以上', '6頭', '1500600380230150', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040208&rf=race_list
#
# ③ 104  	9月12日(日)  	中山 	13	9R     	3歳以上1勝クラス 		> ['9月12日(日)', '結果・払戻', '中山', '9R', '3歳以上1勝クラス', '14:35', ' ダ1800m', 'サラ系３歳以上', '13頭', '76030019011076', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040209&rf=race_list
#
# ③ 105  	9月12日(日)  	中山 	16	10R    	セプテンバー    		> ['9月12日(日)', '結果・払戻', '中山', '10R', 'セプテンバーS', '15:10', ' 芝1200m', 'サラ系３歳以上', '15頭', '1820730460270182', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040210&rf=race_list
#
# ③ 106  	9月12日(日)  	中山 	3	11R    	京成杯AH     		> ['9月12日(日)', '結果・払戻', '中山', '11R', '京成杯AH', '15:45', ' 芝1600m', 'サラ系３歳以上', '16頭', '39001600980590390', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040211&rf=race_list
#
# ③ 107  	9月12日(日)  	中山 		12R    	3歳以上2勝クラス 		> ['9月12日(日)', '結果・払戻', '中山', '12R', '3歳以上2勝クラス', '16:25', ' ダ1200m', 'サラ系３歳以上', '16頭', '1100440280170110', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040212&rf=race_list
#
# ③ 108  	9月12日(日)  	中京 		1R     	2歳未勝利     		> ['9月12日(日)', '結果・払戻', '中京', '1R', '2歳未勝利', '09:50', ' ダ1400m', 'サラ系２歳', '12頭', '5102001307751', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202107050201&rf=race_list
#
# ③ 109  	9月12日(日)  	中京 		2R     	2歳未勝利     		> ['9月12日(日)', '結果・払戻', '中京', '2R', '2歳未勝利', '10:20', ' 芝1400m', 'サラ系２歳', '15頭', '5102001307751', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202107050202&rf=race_list
#
# ③ 120  	9月18日(土)  	中山 		1R     	2歳未勝利     		> ['9月18日(土)', '結果・払戻', '中山', '1R', '2歳未勝利', '10:05', ' ダ1200m', 'サラ系２歳', '16頭', '5102001307751', '雨', '不'] https://race.netkeiba.com/race/result.html?race_id=202106040301&rf=race_list
#
# ③ 121  	9月18日(土)  	中山 		2R     	2歳未勝利     		> ['9月18日(土)', '結果・払戻', '中山', '2R', '2歳未勝利', '10:35', ' ダ1800m', 'サラ系２歳', '10頭', '5102001307751', '雨', '不'] https://race.netkeiba.com/race/result.html?race_id=202106040302&rf=race_list
#
# ③ 122  	9月18日(土)  	中山 		3R     	2歳未勝利     		> ['9月18日(土)', '結果・払戻', '中山', '3R', '2歳未勝利', '11:05', ' 芝1200m', 'サラ系２歳', '16頭', '5102001307751', '雨', '重'] https://race.netkeiba.com/race/result.html?race_id=202106040303&rf=race_list
#
# ③ 123  	9月18日(土)  	中山 		4R     	2歳新馬      		> ['9月18日(土)', '結果・払戻', '中山', '4R', '2歳新馬', '11:35', ' ダ1800m', 'サラ系２歳', '13頭', '70028018011070', '雨', '不'] https://race.netkeiba.com/race/result.html?race_id=202106040304&rf=race_list
#
# ③ 124  	9月18日(土)  	中山 		5R     	2歳新馬      		> ['9月18日(土)', '結果・払戻', '中山', '5R', '2歳新馬', '12:25', ' 芝1800m', 'サラ系２歳', '12頭', '70028018011070', '雨', '重'] https://race.netkeiba.com/race/result.html?race_id=202106040305&rf=race_list
#
# ③ 125  	9月18日(土)  	中山 		6R     	3歳以上1勝クラス 		> ['9月18日(土)', '結果・払戻', '中山', '6R', '3歳以上1勝クラス', '12:55', ' ダ1200m', 'サラ系３歳以上', '14頭', '76030019011076', '雨', '不'] https://race.netkeiba.com/race/result.html?race_id=202106040306&rf=race_list
#
# ③ 126  	9月18日(土)  	中山 		7R     	3歳以上1勝クラス 		> ['9月18日(土)', '結果・払戻', '中山', '7R', '3歳以上1勝クラス', '13:25', ' 芝2500m', 'サラ系３歳以上', '12頭', '76030019011076', '雨', '重'] https://race.netkeiba.com/race/result.html?race_id=202106040307&rf=race_list
#
# ③ 127  	9月18日(土)  	中山 		8R     	3歳以上1勝クラス 		> ['9月18日(土)', '結果・払戻', '中山', '8R', '3歳以上1勝クラス', '14:01', ' ダ1800m', 'サラ系３歳以上', '16頭', '76030019011076', '小雨', '不'] https://race.netkeiba.com/race/result.html?race_id=202106040308&rf=race_list
#
# ③ 128  	9月18日(土)  	中山 	17	9R     	松戸特別      		> ['9月18日(土)', '結果・払戻', '中山', '9R', '松戸特別                                                                                            ', '      14:35', ' ダ2400m', 'サラ系３歳以上', '13頭', '1500600380230150', '曇', '不'] https://race.netkeiba.com/race/result.html?race_id=202106040309&rf=race_list
#
# ③ 129  	9月18日(土)  	中山 	17	10R    	御宿特別      		> ['9月18日(土)', '結果・払戻', '中山', '10R', '御宿特別', '15:10', ' 芝1600m', 'サラ系３歳以上', '14頭', '1500600380230150', '曇', '重'] https://race.netkeiba.com/race/result.html?race_id=202106040310&rf=race_list
#
# ③ 130  	9月18日(土)  	中山 	16	11R    	初風S       		> ['9月18日(土)', '結果・払戻', '中山', '11R', '初風S', '15:45', ' ダ1200m', 'サラ系３歳以上', '16頭', '1820730460270182', '小雨', '不'] https://race.netkeiba.com/race/result.html?race_id=202106040311&rf=race_list
#
# ③ 131  	9月18日(土)  	中山 		12R    	3歳以上1勝クラス 		> ['9月18日(土)', '結果・払戻', '中山', '12R', '3歳以上1勝クラス', '16:25', ' 芝2000m', 'サラ系３歳以上', '16頭', '76030019011076', '曇', '重'] https://race.netkeiba.com/race/result.html?race_id=202106040312&rf=race_list
#
# ③ 132  	9月18日(土)  	中京 		1R     	2歳未勝利     		> ['9月18日(土)', '結果・払戻', '中京', '1R', '2歳未勝利', '09:50', ' ダ1400m', 'サラ系２歳', '11頭', '5102001307751', '雨', '不'] https://race.netkeiba.com/race/result.html?race_id=202107050301&rf=race_list
#
# ③ 133  	9月18日(土)  	中京 		2R     	2歳未勝利     		> ['9月18日(土)', '結果・払戻', '中京', '2R', '2歳未勝利', '10:20', ' ダ1200m', 'サラ系２歳', '10頭', '5102001307751', '雨', '不'] https://race.netkeiba.com/race/result.html?race_id=202107050302&rf=race_list
#
# ③ 134  	9月18日(土)  	中京 		3R     	2歳未勝利     		> ['9月18日(土)', '結果・払戻', '中京', '3R', '2歳未勝利', '10:50', ' 芝1600m', 'サラ系２歳', '14頭', '5102001307751', '雨', '不'] https://race.netkeiba.com/race/result.html?race_id=202107050303&rf=race_list
#
# ③ 135  	9月18日(土)  	中京 		4R     	2歳新馬      		> ['9月18日(土)', '結果・払戻', '中京', '4R', '2歳新馬', '11:20', ' ダ1800m', 'サラ系２歳', '12頭', '70028018011070', '雨', '不'] https://race.netkeiba.com/race/result.html?race_id=202107050304&rf=race_list
#
# ③ 136  	9月18日(土)  	中京 		5R     	2歳新馬      		> ['9月18日(土)', '結果・払戻', '中京', '5R', '2歳新馬', '12:10', ' 芝1200m', 'サラ系２歳', '10頭', '70028018011070', '小雨', '不'] https://race.netkeiba.com/race/result.html?race_id=202107050305&rf=race_list
#
# ③ 137  	9月18日(土)  	中京 		6R     	3歳以上1勝クラス 		> ['9月18日(土)', '結果・払戻', '中京', '6R', '3歳以上1勝クラス', '12:40', ' ダ1800m', 'サラ系３歳以上', '14頭', '76030019011076', '小雨', '不'] https://race.netkeiba.com/race/result.html?race_id=202107050306&rf=race_list
#
# ③ 138  	9月18日(土)  	中京 		7R     	3歳以上1勝クラス 		> ['9月18日(土)', '結果・払戻', '中京', '7R', '3歳以上1勝クラス', '13:15', ' ダ1200m', 'サラ系３歳以上', '13頭', '76030019011076', '小雨', '不'] https://race.netkeiba.com/race/result.html?race_id=202107050307&rf=race_list
#
# ③ 139  	9月18日(土)  	中京 	12	8R     	阪神ジャンプ    		> ['9月18日(土)', '結果・払戻', '中京', '8R', '阪神JS', '13:50', ' 障3300m', '障害３歳以上', '10頭', '29001200730440290', '曇', '不'] https://race.netkeiba.com/race/result.html?race_id=202107050308&rf=race_list
#
# ③ 140  	9月18日(土)  	中京 	18	9R     	金山特別      		> ['9月18日(土)', '結果・払戻', '中京', '9R', '金山特別', '14:25', ' 芝2200m', 'サラ系３歳以上', '13頭', '1060420270160106', '曇', '重'] https://race.netkeiba.com/race/result.html?race_id=202107050309&rf=race_list
#
# ③ 141  	9月18日(土)  	中京 	17	10R    	大府特別      		> ['9月18日(土)', '結果・払戻', '中京', '10R', '大府特別', '15:01', ' ダ1800m', 'サラ系３歳以上', '13頭', '1500600380230150', '曇', '不'] https://race.netkeiba.com/race/result.html?race_id=202107050310&rf=race_list
#
# ③ 142  	9月18日(土)  	中京 	5	11R    	ケフェウスS    		> ['9月18日(土)', '結果・払戻', '中京', '11R', 'ケフェウスS', '15:35', ' 芝2000m', 'サラ系３歳以上', '13頭', '2400960600360240', '曇', '重'] https://race.netkeiba.com/race/result.html?race_id=202107050311&rf=race_list
#
# ③ 143  	9月18日(土)  	中京 		12R    	3歳以上1勝クラス 		> ['9月18日(土)', '結果・払戻', '中京', '12R', '3歳以上1勝クラス', '16:10', ' ダ1400m', 'サラ系３歳以上', '15頭', '76030019011076', '曇', '不'] https://race.netkeiba.com/race/result.html?race_id=202107050312&rf=race_list
#
# ③ 144  	9月19日(日)  	中山 		1R     	2歳未勝利     		> ['9月19日(日)', '結果・払戻', '中山', '1R', '2歳未勝利', '10:05', ' ダ1200m', 'サラ系２歳', '15頭', '5102001307751', '晴', '重'] https://race.netkeiba.com/race/result.html?race_id=202106040401&rf=race_list
#
# ③ 145  	9月19日(日)  	中山 		2R     	2歳未勝利     		> ['9月19日(日)', '結果・払戻', '中山', '2R', '2歳未勝利', '10:35', ' 芝2000m', 'サラ系２歳', '13頭', '5102001307751', '晴', '稍'] https://race.netkeiba.com/race/result.html?race_id=202106040402&rf=race_list
#
# ③ 146  	9月19日(日)  	中山 		3R     	2歳未勝利     		> ['9月19日(日)', '結果・払戻', '中山', '3R', '2歳未勝利', '11:05', ' ダ1800m', 'サラ系２歳', '10頭', '5102001307751', '晴', '重'] https://race.netkeiba.com/race/result.html?race_id=202106040403&rf=race_list
#
# ③ 147  	9月19日(日)  	中山 		4R     	2歳新馬      		> ['9月19日(日)', '結果・払戻', '中山', '4R', '2歳新馬', '11:35', ' 芝1200m', 'サラ系２歳', '16頭', '70028018011070', '晴', '稍'] https://race.netkeiba.com/race/result.html?race_id=202106040404&rf=race_list
#
# ③ 148  	9月19日(日)  	中山 		5R     	2歳新馬      		> ['9月19日(日)', '結果・払戻', '中山', '5R', '2歳新馬', '12:25', ' 芝1600m', 'サラ系２歳', '16頭', '70028018011070', '晴', '稍'] https://race.netkeiba.com/race/result.html?race_id=202106040405&rf=race_list
#
# ③ 149  	9月19日(日)  	中山 		6R     	3歳以上1勝クラス 		> ['9月19日(日)', '結果・払戻', '中山', '6R', '3歳以上1勝クラス', '12:55', ' ダ1200m', 'サラ系３歳以上', '15頭', '76030019011076', '晴', '重'] https://race.netkeiba.com/race/result.html?race_id=202106040406&rf=race_list
#
# ③ 150  	9月19日(日)  	中山 		7R     	3歳以上1勝クラス 		> ['9月19日(日)', '結果・払戻', '中山', '7R', '3歳以上1勝クラス', '13:25', ' 芝1800m', 'サラ系３歳以上', '15頭', '76030019011076', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040407&rf=race_list
#
# ③ 151  	9月19日(日)  	中山 		8R     	3歳以上1勝クラス 		> ['9月19日(日)', '結果・払戻', '中山', '8R', '3歳以上1勝クラス', '14:01', ' ダ2400m', 'サラ系３歳以上', '13頭', '76030019011076', '晴', '稍'] https://race.netkeiba.com/race/result.html?race_id=202106040408&rf=race_list
#
# ③ 152  	9月19日(日)  	中山 	17	9R     	浦安特別      		> ['9月19日(日)', '結果・払戻', '中山', '9R', '浦安特別', '14:35', ' ダ1200m', 'サラ系３歳以上', '15頭', '1500600380230150', '晴', '稍'] https://race.netkeiba.com/race/result.html?race_id=202106040409&rf=race_list
#
# ③ 153  	9月19日(日)  	中山 	16	10R    	レインボーS    		> ['9月19日(日)', '結果・払戻', '中山', '10R', 'レインボーS', '15:10', ' 芝1800m', 'サラ系３歳以上', '15頭', '1820730460270182', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040410&rf=race_list
#
# ③ 154  	9月19日(日)  	中山 	5	11R    	ラジオ日本賞    		> ['9月19日(日)', '結果・払戻', '中山', '11R', 'ラジオ日本賞', '15:45', ' ダ1800m', 'サラ系３歳以上', '16頭', '2200880550330220', '晴', '稍'] https://race.netkeiba.com/race/result.html?race_id=202106040411&rf=race_list
#
# ③ 155  	9月19日(日)  	中山 		12R    	3歳以上1勝クラス 		> ['9月19日(日)', '結果・払戻', '中山', '12R', '3歳以上1勝クラス', '16:25', ' 芝1200m', 'サラ系３歳以上', '15頭', '76030019011076', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040412&rf=race_list
#
# ③ 156  	9月19日(日)  	中京 		1R     	2歳未勝利     		> ['9月19日(日)', '結果・払戻', '中京', '1R', '2歳未勝利', '09:50', ' ダ1400m', 'サラ系２歳', '10頭', '5102001307751', '晴', '重'] https://race.netkeiba.com/race/result.html?race_id=202107050401&rf=race_list
#
# ③ 157  	9月19日(日)  	中京 		2R     	2歳未勝利     		> ['9月19日(日)', '結果・払戻', '中京', '2R', '2歳未勝利', '10:20', ' ダ1800m', 'サラ系２歳', '8頭', '5102001307751', '晴', '重'] https://race.netkeiba.com/race/result.html?race_id=202107050402&rf=race_list
#
# ③ 158  	9月19日(日)  	中京 		3R     	2歳未勝利     		> ['9月19日(日)', '結果・払戻', '中京', '3R', '2歳未勝利', '10:50', ' 芝1200m', 'サラ系２歳', '15頭', '5102001307751', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202107050403&rf=race_list
#
# ③ 159  	9月19日(日)  	中京 		4R     	3歳以上1勝クラス 		> ['9月19日(日)', '結果・払戻', '中京', '4R', '3歳以上1勝クラス', '11:20', ' ダ1400m', 'サラ系３歳以上', '16頭', '76030019011076', '曇', '重'] https://race.netkeiba.com/race/result.html?race_id=202107050404&rf=race_list
#
# ③ 160  	9月19日(日)  	中京 		5R     	2歳新馬      		> ['9月19日(日)', '結果・払戻', '中京', '5R', '2歳新馬', '12:10', ' 芝2000m', 'サラ系２歳', '7頭', '70028018011070', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202107050405&rf=race_list
#
# ③ 161  	9月19日(日)  	中京 		6R     	3歳以上1勝クラス 		> ['9月19日(日)', '結果・払戻', '中京', '6R', '3歳以上1勝クラス', '12:40', ' ダ1900m', 'サラ系３歳以上', '12頭', '76030019011076', '曇', '重'] https://race.netkeiba.com/race/result.html?race_id=202107050406&rf=race_list
#
# ③ 162  	9月19日(日)  	中京 		7R     	3歳以上1勝クラス 		> ['9月19日(日)', '結果・払戻', '中京', '7R', '3歳以上1勝クラス', '13:15', ' ダ1200m', 'サラ系３歳以上', '16頭', '76030019011076', '曇', '重'] https://race.netkeiba.com/race/result.html?race_id=202107050407&rf=race_list
#
# ③ 163  	9月19日(日)  	中京 		8R     	3歳以上1勝クラス 		> ['9月19日(日)', '結果・払戻', '中京', '8R', '3歳以上1勝クラス', '13:50', ' ダ1800m', 'サラ系３歳以上', '13頭', '76030019011076', '曇', '重'] https://race.netkeiba.com/race/result.html?race_id=202107050408&rf=race_list
#
# ③ 164  	9月19日(日)  	中京 	17	9R     	木曽川特別     		> ['9月19日(日)', '結果・払戻', '中京', '9R', '木曽川特別', '14:25', ' 芝2200m', 'サラ系３歳以上', '9頭', '1500600380230150', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202107050409&rf=race_list
#
# ③ 165  	9月19日(日)  	中京 	16	10R    	納屋橋S      		> ['9月19日(日)', '結果・払戻', '中京', '10R', '納屋橋S', '15:01', ' 芝1600m', 'サラ系３歳以上', '12頭', '1820730460270182', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202107050410&rf=race_list
#
# ③ 166  	9月19日(日)  	中京 	2	11R    	ローズS      		> ['9月19日(日)', '結果・払戻', '中京', '11R', 'ローズS', '15:35', ' 芝2000m', 'サラ系３歳', '18頭', '520021001300780520', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202107050411&rf=race_list
#
# ③ 167  	9月19日(日)  	中京 		12R    	3歳以上2勝クラス 		> ['9月19日(日)', '結果・払戻', '中京', '12R', '3歳以上2勝クラス', '16:10', ' ダ1400m', 'サラ系３歳以上', '16頭', '1100440280170110', '曇', '重'] https://race.netkeiba.com/race/result.html?race_id=202107050412&rf=race_list
#
# ③ 168  	9月20日(月)  	中山 		1R     	3歳以上障害未勝利 		> ['9月20日(月)', '結果・払戻', '中山', '1R', '3歳以上障害未勝利', '10:05', ' 障2880m', '障害３歳以上', '14頭', '79032020012079', '晴', '稍'] https://race.netkeiba.com/race/result.html?race_id=202106040501&rf=race_list
#
# ③ 169  	9月20日(月)  	中山 		2R     	2歳未勝利     		> ['9月20日(月)', '結果・払戻', '中山', '2R', '2歳未勝利', '10:40', ' 芝1600m', 'サラ系２歳', '15頭', '5102001307751', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040502&rf=race_list
#
# ③ 170  	9月20日(月)  	中山 		3R     	2歳未勝利     		> ['9月20日(月)', '結果・払戻', '中山', '3R', '2歳未勝利', '11:10', ' ダ1200m', 'サラ系２歳', '13頭', '5102001307751', '晴', '稍'] https://race.netkeiba.com/race/result.html?race_id=202106040503&rf=race_list
#
# ③ 171  	9月20日(月)  	中山 		4R     	2歳未勝利     		> ['9月20日(月)', '結果・払戻', '中山', '4R', '2歳未勝利', '11:40', ' 芝1800m', 'サラ系２歳', '13頭', '5102001307751', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040504&rf=race_list
#
# ③ 172  	9月20日(月)  	中山 		5R     	2歳新馬      		> ['9月20日(月)', '結果・払戻', '中山', '5R', '2歳新馬', '12:30', ' 芝1600m', 'サラ系２歳', '16頭', '70028018011070', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040505&rf=race_list
#
# ③ 173  	9月20日(月)  	中山 		6R     	2歳新馬      		> ['9月20日(月)', '結果・払戻', '中山', '6R', '2歳新馬', '13:00', ' 芝2000m', 'サラ系２歳', '10頭', '70028018011070', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040506&rf=race_list
#
# ③ 174  	9月20日(月)  	中山 		7R     	3歳以上1勝クラス 		> ['9月20日(月)', '結果・払戻', '中山', '7R', '3歳以上1勝クラス', '13:30', ' ダ1800m', 'サラ系３歳以上', '16頭', '76030019011076', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040507&rf=race_list
#
# ③ 175  	9月20日(月)  	中山 		8R     	3歳以上1勝クラス 		> ['9月20日(月)', '結果・払戻', '中山', '8R', '3歳以上1勝クラス', '14:00', ' ダ1200m', 'サラ系３歳以上', '16頭', '76030019011076', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040508&rf=race_list
#
# ③ 176  	9月20日(月)  	中山 	17	9R     	鋸山特別      		> ['9月20日(月)', '結果・払戻', '中山', '9R', '鋸山特別', '14:35', ' ダ1800m', 'サラ系３歳以上', '13頭', '1500600380230150', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040509&rf=race_list
#
# ③ 177  	9月20日(月)  	中山 	17	10R    	Mジャングル    		> ['9月20日(月)', '結果・払戻', '中山', '10R', 'ジャングルポケットC', '15:10', ' 芝2000m', 'サラ系３歳以上', '7頭', '1500600380230150', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040510&rf=race_list
#
# ③ 178  	9月20日(月)  	中山 	2	11R    	セントライト    		> ['9月20日(月)', '結果・払戻', '中山', '11R', 'セントライト記念', '15:45', ' 芝2200m', 'サラ系３歳', '14頭', '540022001400810540', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040511&rf=race_list
#
# ③ 179  	9月20日(月)  	中山 		12R    	3歳以上1勝クラス 		> ['9月20日(月)', '結果・払戻', '中山', '12R', '3歳以上1勝クラス', '16:25', ' ダ1200m', 'サラ系３歳以上', '13頭', '76030019011076', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040512&rf=race_list
#
# ③ 180  	9月20日(月)  	中京 		1R     	2歳未勝利     		> ['9月20日(月)', '結果・払戻', '中京', '1R', '2歳未勝利', '09:50', ' ダ1200m', 'サラ系２歳', '13頭', '5102001307751', '曇', '稍'] https://race.netkeiba.com/race/result.html?race_id=202107050501&rf=race_list
#
# ③ 181  	9月20日(月)  	中京 		2R     	2歳未勝利     		> ['9月20日(月)', '結果・払戻', '中京', '2R', '2歳未勝利', '10:25', ' ダ1800m', 'サラ系２歳', '10頭', '5102001307751', '曇', '稍'] https://race.netkeiba.com/race/result.html?race_id=202107050502&rf=race_list
#
# ③ 182  	9月20日(月)  	中京 		3R     	2歳未勝利     		> ['9月20日(月)', '結果・払戻', '中京', '3R', '2歳未勝利', '10:55', ' 芝2000m', 'サラ系２歳', '10頭', '5102001307751', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202107050503&rf=race_list
#
# ③ 183  	9月20日(月)  	中京 		4R     	2歳新馬      		> ['9月20日(月)', '結果・払戻', '中京', '4R', '2歳新馬', '11:25', ' ダ1400m', 'サラ系２歳', '13頭', '70028018011070', '曇', '稍'] https://race.netkeiba.com/race/result.html?race_id=202107050504&rf=race_list
#
# ③ 184  	9月20日(月)  	中京 		5R     	2歳新馬      		> ['9月20日(月)', '結果・払戻', '中京', '5R', '2歳新馬', '12:15', ' 芝1600m', 'サラ系２歳', '14頭', '70028018011070', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202107050505&rf=race_list
#
# ③ 185  	9月20日(月)  	中京 		6R     	3歳以上1勝クラス 		> ['9月20日(月)', '結果・払戻', '中京', '6R', '3歳以上1勝クラス', '12:45', ' ダ1900m', 'サラ系３歳以上', '13頭', '76030019011076', '曇', '稍'] https://race.netkeiba.com/race/result.html?race_id=202107050506&rf=race_list
#
# ③ 186  	9月20日(月)  	中京 		7R     	3歳以上1勝クラス 		> ['9月20日(月)', '結果・払戻', '中京', '7R', '3歳以上1勝クラス', '13:15', ' ダ1800m', 'サラ系３歳以上', '10頭', '76030019011076', '曇', '稍'] https://race.netkeiba.com/race/result.html?race_id=202107050507&rf=race_list
#
# ③ 187  	9月20日(月)  	中京 		8R     	3歳以上1勝クラス 		> ['9月20日(月)', '結果・払戻', '中京', '8R', '3歳以上1勝クラス', '13:50', ' 芝1600m', 'サラ系３歳以上', '16頭', '76030019011076', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202107050508&rf=race_list
#
# ③ 188  	9月20日(月)  	中京 	18	9R     	ヤマボウシ賞    		> ['9月20日(月)', '結果・払戻', '中京', '9R', 'ヤマボウシ賞', '14:25', ' ダ1400m', 'サラ系２歳', '8頭', '1010400250150101', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202107050509&rf=race_list
#
# ③ 189  	9月20日(月)  	中京 	17	10R    	Mオルフェー    		> ['9月20日(月)', '結果・払戻', '中京', '10R', 'オルフェーヴルC', '15:01', ' 芝1600m', 'サラ系３歳以上', '12頭', '1500600380230150', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202107050510&rf=race_list
#
# ③ 190  	9月20日(月)  	中京 	16	11R    	JRAアニバ    		> ['9月20日(月)', '結果・払戻', '中京', '11R', 'JRAアニバーサリーS', '15:35', ' ダ1800m', 'サラ系３歳以上', '16頭', '1820730460270182', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202107050511&rf=race_list
#
# ③ 191  	9月20日(月)  	中京 		12R    	3歳以上1勝クラス 		> ['9月20日(月)', '結果・払戻', '中京', '12R', '3歳以上1勝クラス', '16:10', ' 芝1200m', 'サラ系３歳以上', '18頭', '76030019011076', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202107050512&rf=race_list
#
# ③ 192  	9月25日(土)  	中山 		1R     	2歳未勝利     		> ['9月25日(土)', '結果・払戻', '中山', '1R', '2歳未勝利', '10:05', ' ダ1200m', 'サラ系２歳', '14頭', '5102001307751', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040601&rf=race_list
#
# ③ 193  	9月25日(土)  	中山 		2R     	2歳未勝利     		> ['9月25日(土)', '結果・払戻', '中山', '2R', '2歳未勝利', '10:35', ' 芝1600m', 'サラ系２歳', '16頭', '5102001307751', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040602&rf=race_list
#
# ③ 194  	9月25日(土)  	中山 		3R     	2歳新馬      		> ['9月25日(土)', '結果・払戻', '中山', '3R', '2歳新馬', '11:05', ' ダ1800m', 'サラ系２歳', '11頭', '70028018011070', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040603&rf=race_list
#
# ③ 195  	9月25日(土)  	中山 		4R     	3歳以上1勝クラス 		> ['9月25日(土)', '結果・払戻', '中山', '4R', '3歳以上1勝クラス', '11:35', ' 芝1200m', 'サラ系３歳以上', '15頭', '76030019011076', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040604&rf=race_list
#
# ③ 196  	9月25日(土)  	中山 		5R     	2歳新馬      		> ['9月25日(土)', '結果・払戻', '中山', '5R', '2歳新馬', '12:25', ' 芝1600m', 'サラ系２歳', '16頭', '70028018011070', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040605&rf=race_list
#
# ③ 197  	9月25日(土)  	中山 		6R     	3歳以上1勝クラス 		> ['9月25日(土)', '結果・払戻', '中山', '6R', '3歳以上1勝クラス', '12:55', ' 芝2000m', 'サラ系３歳以上', '15頭', '76030019011076', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040606&rf=race_list
#
# ③ 198  	9月25日(土)  	中山 		7R     	3歳以上1勝クラス 		> ['9月25日(土)', '結果・払戻', '中山', '7R', '3歳以上1勝クラス', '13:25', ' ダ1800m', 'サラ系３歳以上', '16頭', '76030019011076', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040607&rf=race_list
#
# ③ 199  	9月25日(土)  	中山 	5	8R     	清秋ジャンプ    		> ['9月25日(土)', '結果・払戻', '中山', '8R', '清秋JS', '14:01', ' 障3210m', '障害３歳以上', '14頭', '1650660410250165', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040608&rf=race_list
#
# ③ 200  	9月25日(土)  	中山 	5	9R     	カンナS      		> ['9月25日(土)', '結果・払戻', '中山', '9R', 'カンナS', '14:35', ' 芝1200m', 'サラ系２歳', '10頭', '1600640400240160', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040609&rf=race_list
#
# ③ 201  	9月25日(土)  	中山 	17	10R    	九十九里特別    		> ['9月25日(土)', '結果・払戻', '中山', '10R', '九十九里特別', '15:10', ' 芝2500m', 'サラ系３歳以上', '12頭', '1500600380230150', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040610&rf=race_list
#
# ③ 202  	9月25日(土)  	中山 	5	11R    	ながつきS     		> ['9月25日(土)', '結果・払戻', '中山', '11R', 'ながつきS', '15:45', ' ダ1200m', 'サラ系３歳以上', '16頭', '2200880550330220', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040611&rf=race_list
#
# ③ 203  	9月25日(土)  	中山 		12R    	3歳以上2勝クラス 		> ['9月25日(土)', '結果・払戻', '中山', '12R', '3歳以上2勝クラス', '16:25', ' ダ1800m', 'サラ系３歳以上', '16頭', '1100440280170110', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040612&rf=race_list
#
# ③ 204  	9月25日(土)  	中京 		1R     	2歳未勝利     		> ['9月25日(土)', '結果・払戻', '中京', '1R', '2歳未勝利', '09:50', ' ダ1400m', 'サラ系２歳', '8頭', '5102001307751', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202107050601&rf=race_list
#
# ③ 205  	9月25日(土)  	中京 		2R     	2歳未勝利     		> ['9月25日(土)', '結果・払戻', '中京', '2R', '2歳未勝利', '10:20', ' ダ1800m', 'サラ系２歳', '10頭', '5102001307751', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202107050602&rf=race_list
#
# ③ 206  	9月25日(土)  	中京 		3R     	2歳未勝利     		> ['9月25日(土)', '結果・払戻', '中京', '3R', '2歳未勝利', '10:50', ' 芝2000m', 'サラ系２歳', '11頭', '5102001307751', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202107050603&rf=race_list
#
# ③ 207  	9月25日(土)  	中京 		4R     	2歳新馬      		> ['9月25日(土)', '結果・払戻', '中京', '4R', '2歳新馬', '11:20', ' ダ1400m', 'サラ系２歳', '13頭', '70028018011070', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202107050604&rf=race_list
#
# ③ 208  	9月25日(土)  	中京 		5R     	2歳新馬      		> ['9月25日(土)', '結果・払戻', '中京', '5R', '2歳新馬', '12:10', ' 芝1400m', 'サラ系２歳', '16頭', '70028018011070', '晴', '良'] https://race.netkeiba.com/race/result.html?race_id=202107050605&rf=race_list
#
# ③ 209  	9月25日(土)  	中京 		6R     	3歳以上1勝クラス 		> ['9月25日(土)', '結果・払戻', '中京', '6R', '3歳以上1勝クラス', '12:40', ' ダ1200m', 'サラ系３歳以上', '14頭', '76030019011076', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202107050606&rf=race_list
#
# ③ 210  	9月25日(土)  	中京 		7R     	3歳以上1勝クラス 		> ['9月25日(土)', '結果・払戻', '中京', '7R', '3歳以上1勝クラス', '13:15', ' ダ1800m', 'サラ系３歳以上', '10頭', '76030019011076', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202107050607&rf=race_list
#
# ③ 211  	9月25日(土)  	中京 		8R     	3歳以上1勝クラス 		> ['9月25日(土)', '結果・払戻', '中京', '8R', '3歳以上1勝クラス', '13:50', ' ダ1400m', 'サラ系３歳以上', '16頭', '76030019011076', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202107050608&rf=race_list
#
# ③ 212  	9月25日(土)  	中京 	5	9R     	野路菊S      		> ['9月25日(土)', '結果・払戻', '中京', '9R', '野路菊S', '14:25', ' 芝2000m', 'サラ系２歳', '8頭', '1600640400240160', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202107050609&rf=race_list
#
# ③ 213  	9月25日(土)  	中京 	17	10R    	夕月特別      		> ['9月25日(土)', '結果・払戻', '中京', '10R', '夕月特別', '15:01', ' 芝2000m', 'サラ系３歳以上', '9頭', '1500600380230150', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202107050610&rf=race_list
#
# ③ 214  	9月25日(土)  	中京 	16	11R    	長篠S       		> ['9月25日(土)', '結果・払戻', '中京', '11R', '長篠S', '15:35', ' 芝1200m', 'サラ系３歳以上', '16頭', '1820730460270182', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202107050611&rf=race_list
#
# ③ 215  	9月25日(土)  	中京 		12R    	3歳以上2勝クラス 		> ['9月25日(土)', '結果・払戻', '中京', '12R', '3歳以上2勝クラス', '16:10', ' ダ1800m', 'サラ系３歳以上', '16頭', '1100440280170110', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202107050612&rf=race_list
#
# ③ 216  	9月26日(日)  	中山 		1R     	2歳未勝利     		> ['9月26日(日)', '結果・払戻', '中山', '1R', '2歳未勝利', '10:05', ' ダ1800m', 'サラ系２歳', '12頭', '5102001307751', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040701&rf=race_list
#
# ③ 217  	9月26日(日)  	中山 		2R     	2歳未勝利     		> ['9月26日(日)', '結果・払戻', '中山', '2R', '2歳未勝利', '10:40', ' 芝1200m', 'サラ系２歳', '13頭', '5102001307751', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040702&rf=race_list
#
# ③ 218  	9月26日(日)  	中山 		3R     	2歳未勝利     		> ['9月26日(日)', '結果・払戻', '中山', '3R', '2歳未勝利', '11:10', ' 芝1800m', 'サラ系２歳', '14頭', '5102001307751', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040703&rf=race_list
#
# ③ 219  	9月26日(日)  	中山 		4R     	2歳新馬      		> ['9月26日(日)', '結果・払戻', '中山', '4R', '2歳新馬', '11:45', ' ダ1200m', 'サラ系２歳', '16頭', '70028018011070', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040704&rf=race_list
#
# ③ 220  	9月26日(日)  	中山 		5R     	2歳新馬      		> ['9月26日(日)', '結果・払戻', '中山', '5R', '2歳新馬', '12:30', ' 芝2000m', 'サラ系２歳', '17頭', '70028018011070', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040705&rf=race_list
#
# ③ 221  	9月26日(日)  	中山 		6R     	3歳以上1勝クラス 		> ['9月26日(日)', '結果・払戻', '中山', '6R', '3歳以上1勝クラス', '13:00', ' ダ1200m', 'サラ系３歳以上', '16頭', '76030019011076', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040706&rf=race_list
#
# ③ 222  	9月26日(日)  	中山 		7R     	3歳以上1勝クラス 		> ['9月26日(日)', '結果・払戻', '中山', '7R', '3歳以上1勝クラス', '13:30', ' 芝1600m', 'サラ系３歳以上', '15頭', '76030019011076', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040707&rf=race_list
#
# ③ 223  	9月26日(日)  	中山 		8R     	3歳以上1勝クラス 		> ['9月26日(日)', '結果・払戻', '中山', '8R', '3歳以上1勝クラス', '14:01', ' ダ1800m', 'サラ系３歳以上', '16頭', '76030019011076', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040708&rf=race_list
#
# ③ 224  	9月26日(日)  	中山 	17	9R     	木更津特別     		> ['9月26日(日)', '結果・払戻', '中山', '9R', '木更津特別', '14:35', ' 芝1600m', 'サラ系３歳以上', '13頭', '1500600380230150', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040709&rf=race_list
#
# ③ 225  	9月26日(日)  	中山 	16	10R    	内房S       		> ['9月26日(日)', '結果・払戻', '中山', '10R', '内房S', '15:10', ' ダ1800m', 'サラ系３歳以上', '16頭', '1820730460270182', '小雨', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040710&rf=race_list
#
# ③ 226  	9月26日(日)  	中山 	2	11R    	オールカマー    		> ['9月26日(日)', '結果・払戻', '中山', '11R', 'オールカマー', '15:45', ' 芝2200m', 'サラ系３歳以上', '16頭', '6700270017001000670', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040711&rf=race_list
#
# ③ 227  	9月26日(日)  	中山 		12R    	3歳以上2勝クラス 		> ['9月26日(日)', '結果・払戻', '中山', '12R', '3歳以上2勝クラス', '16:25', ' ダ1200m', 'サラ系３歳以上', '16頭', '1100440280170110', '曇', '良'] https://race.netkeiba.com/race/result.html?race_id=202106040712&rf=race_list
#
# ③ 228  	9月26日(日)  	中京 		1R     	3歳以上障害未勝利 		> ['9月26日(日)', '結果・払戻', '中京', '1R', '3歳以上障害未勝利', '09:50', ' 障3000m', '障害３歳以上', '14頭', '79032020012079', '雨', '稍'] https://race.netkeiba.com/race/result.html?race_id=202107050701&rf=race_list
#
# ③ 229  	9月26日(日)  	中京 		2R     	2歳未勝利     		> ['9月26日(日)', '結果・払戻', '中京', '2R', '2歳未勝利', '10:25', ' ダ1800m', 'サラ系２歳', '10頭', '5102001307751', '雨', '重'] https://race.netkeiba.com/race/result.html?race_id=202107050702&rf=race_list
#
# ③ 230  	9月26日(日)  	中京 		3R     	2歳未勝利     		> ['9月26日(日)', '結果・払戻', '中京', '3R', '2歳未勝利', '10:55', ' 芝1600m', 'サラ系２歳', '12頭', '5102001307751', '雨', '重'] https://race.netkeiba.com/race/result.html?race_id=202107050703&rf=race_list
#
# ③ 231  	9月26日(日)  	中京 		4R     	2歳新馬      		> ['9月26日(日)', '結果・払戻', '中京', '4R', '2歳新馬', '11:25', ' ダ1200m', 'サラ系２歳', '12頭', '70028018011070', '雨', '不'] https://race.netkeiba.com/race/result.html?race_id=202107050704&rf=race_list
#
# ③ 232  	9月26日(日)  	中京 		5R     	2歳新馬      		> ['9月26日(日)', '結果・払戻', '中京', '5R', '2歳新馬', '12:15', ' 芝2000m', 'サラ系２歳', '11頭', '70028018011070', '雨', '重'] https://race.netkeiba.com/race/result.html?race_id=202107050705&rf=race_list
#
# ③ 233  	9月26日(日)  	中京 		6R     	3歳以上1勝クラス 		> ['9月26日(日)', '結果・払戻', '中京', '6R', '3歳以上1勝クラス', '12:45', ' ダ1800m', 'サラ系３歳以上', '14頭', '76030019011076', '雨', '不'] https://race.netkeiba.com/race/result.html?race_id=202107050706&rf=race_list
#
# ③ 234  	9月26日(日)  	中京 		7R     	3歳以上1勝クラス 		> ['9月26日(日)', '結果・払戻', '中京', '7R', '3歳以上1勝クラス', '13:15', ' ダ1900m', 'サラ系３歳以上', '10頭', '76030019011076', '雨', '不'] https://race.netkeiba.com/race/result.html?race_id=202107050707&rf=race_list
#
# ③ 235  	9月26日(日)  	中京 		8R     	3歳以上1勝クラス 		> ['9月26日(日)', '結果・払戻', '中京', '8R', '3歳以上1勝クラス', '13:50', ' 芝2000m', 'サラ系３歳以上', '10頭', '76030019011076', '雨', '重'] https://race.netkeiba.com/race/result.html?race_id=202107050708&rf=race_list
#
# ③ 236  	9月26日(日)  	中京 	17	9R     	知多特別      		> ['9月26日(日)', '結果・払戻', '中京', '9R', '知多特別', '14:25', ' 芝1200m', 'サラ系３歳以上', '18頭', '1500600380230150', '雨', '重'] https://race.netkeiba.com/race/result.html?race_id=202107050709&rf=race_list
#
# ③ 237  	9月26日(日)  	中京 	16	10R    	桶狭間S      		> ['9月26日(日)', '結果・払戻', '中京', '10R', '桶狭間S', '15:01', ' ダ1400m', 'サラ系３歳以上', '16頭', '1820730460270182', '雨', '不'] https://race.netkeiba.com/race/result.html?race_id=202107050710&rf=race_list
#
# ③ 238  	9月26日(日)  	中京 	2	11R    	神戸新聞杯     		> ['9月26日(日)', '結果・払戻', '中京', '11R', '神戸新聞杯', '15:35', ' 芝2200m', 'サラ系３歳', '10頭', '540022001400810540', '雨', '不'] https://race.netkeiba.com/race/result.html?race_id=202107050711&rf=race_list
#
# ③ 239  	9月26日(日)  	中京 		12R    	3歳以上2勝クラス 		> ['9月26日(日)', '結果・払戻', '中京', '12R', '3歳以上2勝クラス', '16:10', ' ダ1200m', 'サラ系３歳以上', '16頭', '1100440280170110', '雨', '不'] https://race.netkeiba.com/race/result.html?race_id=202107050712&rf=race_list
#
# ③ 240  	10月2日(土)  	中山 	5	9R     	芙蓉S       		> ['10月2日(土)', '出馬表', '中山', '9R', '芙蓉ステークス', ' 芝2000m (右)', ' 芝2000m', 'サラ系２歳', '12頭', '1600640400240160', '', ''] https://race.netkeiba.com/race/shutuba.html?race_id=202106040809&rf=race_list
#
# ③ 241  	10月2日(土)  	中山 	17	10R    	勝浦特別      		> ['10月2日(土)', '出馬表', '中山', '10R', '勝浦特別', ' 芝1200m (右 外)', ' 芝1200m', 'サラ系３歳以上', '22頭', '1500600380230150', '', ''] https://race.netkeiba.com/race/shutuba.html?race_id=202106040810&rf=race_list
#
# ③ 242  	10月2日(土)  	中山 	16	11R    	秋風S       		> ['10月2日(土)', '出馬表', '中山', '11R', '秋風ステークス', ' 芝1600m (右 外)', ' 芝1600m', 'サラ系３歳以上', '15頭', '1820730460270182', '', ''] https://race.netkeiba.com/race/shutuba.html?race_id=202106040811&rf=race_list
#
# ③ 243  	10月2日(土)  	中京 	5	9R     	ききょうS     		> ['10月2日(土)', '出馬表', '中京', '9R', 'ききょうステークス', ' 芝1400m (左)', ' 芝1400m', 'サラ系２歳', '9頭', '1600640400240160', '', ''] https://race.netkeiba.com/race/shutuba.html?race_id=202107050809&rf=race_list
#
# ③ 244  	10月2日(土)  	中京 	16	10R    	関ケ原S      		> ['10月2日(土)', '出馬表', '中京', '10R', '関ケ原ステークス', ' 芝2000m (左)', ' 芝2000m', 'サラ系３歳以上', '14頭', '1820730460270182', '', ''] https://race.netkeiba.com/race/shutuba.html?race_id=202107050810&rf=race_list
#
# ③ 245  	10月2日(土)  	中京 	3	11R    	シリウスS     		> ['10月2日(土)', '出馬表', '中京', '11R', 'シリウスステークス', '15:35', ' ダ1900m', 'サラ系３歳以上', '22頭', '36001400900540360', '', ''] https://race.netkeiba.com/race/shutuba.html?race_id=202107050811&rf=race_list
#
# ③ 246  	10月3日(日)  	中山 	18	9R     	サフラン賞     		> ['10月3日(日)', '出馬表', '中山', '9R', 'サフラン賞', '14:25', ' 芝1600m', 'サラ系２歳', '12頭', '1010400250150101', '', ''] https://race.netkeiba.com/race/shutuba.html?race_id=202106040909&rf=race_list
#
# ③ 247  	10月3日(日)  	中山 	17	10R    	茨城新聞杯     		> ['10月3日(日)', '出馬表', '中山', '10R', '茨城新聞杯', '15:00', ' 芝1800m', 'サラ系３歳以上', '18頭', '1500600380230150', '', ''] https://race.netkeiba.com/race/shutuba.html?race_id=202106040910&rf=race_list
#
# ③ 248  	10月3日(日)  	中山 	1	11R    	スプリンター    		> ['10月3日(日)', '出馬表', '中山', '11R', 'スプリンターズS', '15:40', ' 芝1200m', 'サラ系３歳以上', '22頭', '130005200330020001300', '', ''] https://race.netkeiba.com/race/shutuba.html?race_id=202106040911&rf=race_list
#
# ③ 249  	10月3日(日)  	中山 	16	12R    	外房S       		> ['10月3日(日)', '出馬表', '中山', '12R', '外房ステークス', ' ダ1200m (右)', ' ダ1200m', 'サラ系３歳以上', '35頭', '1820730460270182', '', ''] https://race.netkeiba.com/race/shutuba.html?race_id=202106040912&rf=race_list
#
# ③ 250  	10月3日(日)  	中京 	17	9R     	浜名湖特別     		> ['10月3日(日)', '出馬表', '中京', '9R', '浜名湖特別', ' 芝2000m (左)', ' 芝2000m', 'サラ系３歳以上', '15頭', '1500600380230150', '', ''] https://race.netkeiba.com/race/shutuba.html?race_id=202107050909&rf=race_list
#
# ③ 251  	10月3日(日)  	中京 	16	10R    	白川郷S      		> ['10月3日(日)', '出馬表', '中京', '10R', '白川郷ステークス', '14:50', ' ダ1900m', 'サラ系３歳以上', '27頭', '1820730460270182', '', ''] https://race.netkeiba.com/race/shutuba.html?race_id=202107050910&rf=race_list
#
# ③ 252  	10月3日(日)  	中京 	15	11R    	ポートアイS    		> ['10月3日(日)', '出馬表', '中京', '11R', 'ポートアイランドステークス', '15:30', ' 芝1600m', 'サラ系３歳以上', '27頭', '25001000630380250', '', ''] https://race.netkeiba.com/race/shutuba.html?race_id=202107050911&rf=race_list

# %%
results1_df
# Out:
#           ymd  ...                                                url
# 0    20210904  ...  https://race.netkeiba.com/race/result.html?rac...
# 1    20210904  ...  https://race.netkeiba.com/race/result.html?rac...
# 2    20210904  ...  https://race.netkeiba.com/race/result.html?rac...
# 3    20210904  ...  https://race.netkeiba.com/race/result.html?rac...
# 4    20210904  ...  https://race.netkeiba.com/race/result.html?rac...
# ..        ...  ...                                                ...
# 248  20211003  ...  https://race.netkeiba.com/race/shutuba.html?ra...
# 249  20211003  ...  https://race.netkeiba.com/race/shutuba.html?ra...
# 250  20211003  ...  https://race.netkeiba.com/race/shutuba.html?ra...
# 251  20211003  ...  https://race.netkeiba.com/race/shutuba.html?ra...
# 252  20211003  ...  https://race.netkeiba.com/race/shutuba.html?ra...
#
# [253 rows x 16 columns]

# %%
results2_df
# Out:
#      rank waku umaban  ... weight weight_change       race_id
# 0       1    1      1  ...    490            +6  202104040701
# 1       2    2      2  ...    462            +2  202104040701
# 2       3    5      7  ...    510            -2  202104040701
# 3       4    4      5  ...    482            +2  202104040701
# 4       5    3      3  ...    500            -6  202104040701
# ...   ...  ...    ...  ...    ...           ...           ...
# 3464                   ...                       202107050911
# 3465                   ...                       202107050911
# 3466                   ...                       202107050911
# 3467                   ...                       202107050911
# 3468                   ...                       202107050911
#
# [3469 rows x 21 columns]

# %%
results1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ymd            253 non-null    int64
#  1   date           253 non-null    object
#  2   menu           253 non-null    object
#  3   place          253 non-null    object
#  4   r              253 non-null    object
#  5   title          253 non-null    object
#  6   start_time     253 non-null    object
#  7   distance       253 non-null    object
#  8   race_type      253 non-null    object
#  9   number         253 non-null    object
#  10  prize          253 non-null    object
#  11  weather        253 non-null    object
#  12  course_status  253 non-null    object
#  13  grade          253 non-null    object
#  14  race_id        253 non-null    object
#  15  url            253 non-null    object
# dtypes: int64(1), object(15)
# memory usage: 31.8+ KB

# %% [markdown]
# ### **SQLite出力**

# %%
# データベース（db1）を作成（既に存在していれば接続）
conn = sqlite3.connect('dbkeiba')

# %%
# SQLiteを操作するためのカーソルを作成
cur = conn.cursor()

# %%
# テーブル（table1）が存在していれば削除
cur.execute('DROP TABLE IF EXISTS info')

# テーブル（info）を作成
cur.execute("""CREATE TABLE info(
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    ymd INT, 
    date TEXT, 
    menu TEXT, 
    place TEXT, 
    r TEXT, 
    title TEXT, 
    start_time TEXT, 
    distance TEXT, 
    race_type TEXT, 
    number TEXT, 
    prize TEXT, 
    weather TEXT, 
    course_status TEXT, 
    grade TEXT, 
    race_id TEXT, 
    url TEXT)
""")

# %% [markdown]
# #### 1レコードの追加

# %%
# 1レース分のレース情報のリストを作成
data = results1_df.copy().iloc[0].tolist()

# ymdをnumpy.int64からint型に変換
data[0] = int(data[0])

# データ登録4
cur.execute('INSERT INTO info (ymd, date, menu, place, r, title, start_time, distance, race_type, number, prize, weather, course_status, grade, race_id, url) VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)', data)

# コミット
conn.commit()

# %%
# データの読み取り（全レコード）
cur.execute('SELECT * FROM info')

# 結果の表示
print(cur.fetchall())
# Out:
# [(1, 20210904, '9月4日(土)', '結果・払戻', '新潟', '1R', '3歳以上障害未勝利', '10:10', ' 障2850m', '障害３歳以上', '13頭', '79032020012079', '曇', '稍', '', '202104040701', 'https://race.netkeiba.com/race/result.html?race_id=202104040701&rf=race_list')]

# %%
df_db = results1_df.copy()
df_db
# Out:
#         ymd  ...                                                url
# 1  20210904  ...  https://race.netkeiba.com/race/result.html?rac...
# 2  20210904  ...  https://race.netkeiba.com/race/result.html?rac...
# 3  20210904  ...  https://race.netkeiba.com/race/result.html?rac...
#
# [3 rows x 16 columns]

# %%
# テーブル（table1）が存在していれば削除
cur.execute('DROP TABLE IF EXISTS db2')

# DataFrameをまとめてデータベースに追加
results1_df.to_sql('db2', conn, if_exists='replace', index=None, method='multi')

# %%
# データの読み取り（全レコード）
result = cur.execute('SELECT * FROM db2').fetchall()

# 結果の表示
print(result)
# Out:
# [(20210904, '9月4日(土)', '結果・払戻', '新潟', '1R', '3歳以上障害未勝利', '10:10', ' 障2850m', '障害３歳以上', '13頭', '79032020012079', '曇', '稍', '', '202104040701', 'https://race.netkeiba.com/race/result.html?race_id=202104040701&rf=race_list'), (20210904, '9月4日(土)', '結果・払戻', '新潟', '2R', '2歳未勝利', '10:45', ' ダ1800m', 'サラ系２歳', '15頭', '5102001307751', '曇', '稍', '', '202104040702', 'https://race.netkeiba.com/race/result.html?race_id=202104040702&rf=race_list'), (20210904, '9月4日(土)', '結果・払戻', '新潟', '3R', '3歳未勝利', '11:15', ' ダ1800m', 'サラ系３歳', '15頭', '5102001307751
勝利', '11:05', ' 芝1200m', 'サラ系３歳', '18頭', '5102001307751', '曇', '重', '', '202110040703', 'https://race.netkeiba.com/race/result.html?race_id=202110040703&rf=race_list'), (20210904, '9月4日(土)', '結果・払戻', '小倉', '4R', '3歳未勝利', '11:35', ' 芝2000m', 'サラ系３歳', '18頭', '5102001307751', '曇', '重', '', '202110040704', 'https://race.netkeiba.com/race/result.html?race_id=202110040704&rf=race_list'), (20210904, '9月4日(土)', '結果・払戻', '小倉', '5R', '2歳新馬', '12:25', ' 芝1200m', 'サラ系２歳', '13頭', '70028018011070', '曇', '稍', '', '202110040705', 'https://race.netkeiba.com/race/result.html?race_id=202110040705&rf=race_list'), (20210904, '9月4日(土)', '結果・払戻', '小倉', '6R', '3歳未勝利', '12:55', ' ダ1000m', 'サラ系３歳', '14頭', '5102001307751', '曇', '重', '', '202110040706', 'https://race.netkeiba.com/race/result.html?race_id=202110040706&rf=race_list'), (20210904, '9月4日(土)', '結果・払戻', '小倉', '7R', '3歳以上1勝クラス', '13:25 ...

# %%
# カラム（フィールド：列）一覧を表示する【 "PRAGMA TABLE_INFO(テーブル名) "】
columns_info = cur.execute("PRAGMA TABLE_INFO(db2)").fetchall()

# カラム名のリスト
columns = np.array(columns_info)[:,1].tolist()

# データフレームとして表示
pd.DataFrame(result, columns=columns)
# Out:
#           ymd  ...                                                url
# 0    20210904  ...  https://race.netkeiba.com/race/result.html?rac...
# 1    20210904  ...  https://race.netkeiba.com/race/result.html?rac...
# 2    20210904  ...  https://race.netkeiba.com/race/result.html?rac...
# 3    20210904  ...  https://race.netkeiba.com/race/result.html?rac...
# 4    20210904  ...  https://race.netkeiba.com/race/result.html?rac...
# ..        ...  ...                                                ...
# 248  20211003  ...  https://race.netkeiba.com/race/shutuba.html?ra...
# 249  20211003  ...  https://race.netkeiba.com/race/shutuba.html?ra...
# 250  20211003  ...  https://race.netkeiba.com/race/shutuba.html?ra...
# 251  20211003  ...  https://race.netkeiba.com/race/shutuba.html?ra...
# 252  20211003  ...  https://race.netkeiba.com/race/shutuba.html?ra...
#
# [253 rows x 16 columns]

# %% [markdown]
# ### **ファイルをドライブにコピー**

# %%
# ドライブコピー（ ② レース情報 ）

# コピー元のファイルパス
fp_info = 'RaceInfoTable_latest.csv'

# コピーファイル名
fp_info_copy = '/content/drive/My Drive/開発/1_WebScraper/netkeiba/data/' + fp_info

# SQLiteファイルをColabデフォルトディレクトリ内にコピー
shutil.copy(fp_info, fp_info_copy)
# Out:
# '/content/drive/My Drive/開発/1_WebScraper/netkeiba/data/RaceInfoTable_latest.csv'

# %%
# ドライブコピー（ ③ レース結果 ）

# コピー元のファイルパス
fp_result = 'RaceResultTable_latest.csv'

# コピーファイル名
fp_result_copy = '/content/drive/My Drive/開発/1_WebScraper/netkeiba/data/' + fp_result

# SQLiteファイルをColabデフォルトディレクトリ内にコピー
shutil.copy(fp_result, fp_result_copy)
# Out:
# '/content/drive/My Drive/開発/1_WebScraper/netkeiba/data/RaceResultTable_latest.csv'
